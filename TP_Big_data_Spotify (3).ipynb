# %% [markdown]
# <a href="https://colab.research.google.com/github/carosen003/Big-Data/blob/main/TP_Big_data_Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Preprocesamiento de Datos: Limpien y preparen los datos de canciones y escuchas para el análisis.**
# Excel en crudo
#
# ![WhatsApp Image 2024-06-11 at 13.18.15.jpeg](data:image/jpeg;base64,...)
#
#
#
# Excel Luego de la limpieza
# ![WhatsApp Image 2024-06-11 at 13.18.53.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Exploración de Datos (EDA): Analicen las características de las canciones, como género, artista, popularidad, duración, etc.**

# %%
pip install retrying
# Out:
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying) (1.16.0)
# Installing collected packages: retrying
# Successfully installed retrying-1.3.4

# %%
pip install plotly dash
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Collecting dash
#   Downloading dash-2.17.1-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 48.7 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash) (3.0.3)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash) (7.1.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash) (2.31.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash) (67.7.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<3.1->dash) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2024.6.2)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dash) (1.16.0)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, dash
# Successfully installed dash-2.17.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0

# %%
pip install requests spotipy pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Collecting spotipy
#   Downloading spotipy-2.24.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.6-py3-none-any.whl (252 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.6 spotipy-2.24.0

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.10/dist-packages (2.24.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.10/dist-packages (from spotipy) (5.0.6)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.31.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.0.7)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2024.6.2)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd

# %%
# Credenciales de la aplicación de Spotify
client_id = '451aa62bae54460285deb9a8a0921675'
client_secret = '4c31e871561a4aaeabf7e2c183504e47'

# Autenticación
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Ejemplo: Obtener detalles de una canción específica
track_id = '297Ev6aeDHc8dECDmK7SFH'
track = sp.track(track_id)
print(track)
# Out:
# {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YCc6xS5Gpj3EkaYGdjyNK'}, 'href': 'https://api.spotify.com/v1/artists/5YCc6xS5Gpj3EkaYGdjyNK', 'id': '5YCc6xS5Gpj3EkaYGdjyNK', 'name': 'WOS', 'type': 'artist', 'uri': 'spotify:artist:5YCc6xS5Gpj3EkaYGdjyNK'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0t9xw4VcPabCkwVO77u31Z'}, 'href': 'https://api.spotify.com/v1/albums/0t9xw4VcPabCkwVO77u31Z', 'id': '0t9xw4VcPabCkwVO77u31Z', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273c678828a5678109a13f20ba2', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02c678828a5678109a13f20ba2', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851c678828a5678109a13f20ba2', 'width': 64}], 'name': 'DESCARTABLE', 'release_date': '2024-03-21', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:0t9xw4VcPabCkwVO77u31Z'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YCc6xS5Gpj3EkaYGdjyNK'}, 'href': 'https://api.spotify.com/v1/artists/5YCc6xS5Gpj3EkaYGdjyNK', 'id': '5YCc6xS5Gpj3EkaYGdjyNK', 'name': 'WOS', 'type': 'artist', 'uri': 'spotify:artist:5YCc6xS5Gpj3EkaYGdjyNK'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 233046, 'explicit': False, 'external_ids': {'isrc': 'UYB282306013'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/297Ev6aeDHc8dECDmK7SFH'}, 'href': 'https://api.spotify.com/v1/tracks/297Ev6aeDHc8dECDmK7SFH', 'id': '297Ev6aeDHc8dECDmK7SFH', 'is_local': False, 'name': 'MORFEO', 'popularity': 55, 'preview_url': 'https://p.scdn.co/mp3-preview/8b44f84860a0b0523c6a1c2ac14626327a4c9125?cid=451aa62ba ...

# %%
import requests
from PIL import Image
from io import BytesIO
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from IPython.display import display

# Credenciales de la aplicación de Spotify
client_id = '451aa62bae54460285deb9a8a0921675'
client_secret = '4c31e871561a4aaeabf7e2c183504e47'

# Autenticación
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Ejemplo: Obtener detalles de una canción específica
track_id = '5wG3HvLhF6Y5KTGlK0IW3J'
track = sp.track(track_id)

# Obtener el enlace de la imagen del álbum
album_image_url = track['album']['images'][0]['url']

# Imprimir la URL de la imagen del álbum
print(f"URL de la imagen del álbum: {album_image_url}")

# Descargar la imagen
response = requests.get(album_image_url)
img = Image.open(BytesIO(response.content))

# Mostrar la imagen en Jupyter Notebook
display(img)
# Out:
# URL de la imagen del álbum: https://i.scdn.co/image/ab67616d0000b273c4fee55d7b51479627c31f89
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
import requests
from PIL import Image
from io import BytesIO
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from IPython.display import display

# Credenciales de la aplicación de Spotify
client_id = '451aa62bae54460285deb9a8a0921675'
client_secret = '4c31e871561a4aaeabf7e2c183504e47'

# Autenticación
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def print_track_details(track_name):
    # Buscar la canción por nombre
    results = sp.search(q=f'track:{track_name}', type='track', limit=1)
    tracks = results['tracks']['items']

    if not tracks:
        print(f"No se encontró ninguna canción con el nombre: {track_name}")
        return

    # Obtener el primer resultado
    track = tracks[0]

    # Imprimir los detalles de la canción en forma vertical
    print("Detalles de la canción:")
    print(f"Nombre: {track['name']}")
    print(f"Álbum: {track['album']['name']}")
    print(f"Artistas: {', '.join([artist['name'] for artist in track['artists']])}")
    print(f"ID de la canción: {track['id']}")
    print(f"Duración (ms): {track['duration_ms']}")
    print(f"Popularidad: {track['popularity']}")
    print(f"Vista previa de la URL: {track['preview_url']}")
    print(f"URL de Spotify: {track['external_urls']['spotify']}")

    # Obtener el enlace de la imagen del álbum
    album_image_url = track['album']['images'][0]['url']
    print(f"URL de la imagen del álbum: {album_image_url}")

    # Descargar la imagen
    response = requests.get(album_image_url)
    img = Image.open(BytesIO(response.content))

    # Redimensionar la imagen
    img = img.resize((200, 200))  # Ajustar el tamaño de la imagen (puedes cambiar los valores según tus necesidades)

    # Mostrar la imagen
    display(img)

# Ejemplo de uso
track_name = 'Circles'
print_track_details(track_name)
# Out:
# Detalles de la canción:
# Nombre: Circles
# Álbum: Hollywood's Bleeding
# Artistas: Post Malone
# ID de la canción: 21jGcNKet2qwijlDFuPiPb
# Duración (ms): 215280
# Popularidad: 80
# Vista previa de la URL: None
# URL de Spotify: https://open.spotify.com/track/21jGcNKet2qwijlDFuPiPb
# URL de la imagen del álbum: https://i.scdn.co/image/ab67616d0000b2739478c87599550dd73bfa7e02
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
df = pd.read_csv('/content/spotify_dataset.csv')
print(df.head())
# Out:
#    user_id                        artistname  \
# 0        1                    Elvis Costello
# 1        1  Elvis Costello & The Attractions
# 2        1                      Tiffany Page
# 3        1  Elvis Costello & The Attractions
# 4        1                    Elvis Costello
#
#                                            song_name
# 0               (The Angels Wanna Wear My) Red Shoes
# 1  (What's So Funny 'Bout) Peace, Love And Unders...
# 2                                   7 Years Too Late
# 3                              Accidents Will Happen
# 4                                             Alison

# %%
df.head()
# Out:
#    user_id                        artistname  \
# 0        1                    Elvis Costello
# 1        1  Elvis Costello & The Attractions
# 2        1                      Tiffany Page
# 3        1  Elvis Costello & The Attractions
# 4        1                    Elvis Costello
#
#                                            song_name
# 0               (The Angels Wanna Wear My) Red Shoes
# 1  (What's So Funny 'Bout) Peace, Love And Unders...
# 2                                   7 Years Too Late
# 3                              Accidents Will Happen
# 4                                             Alison

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      459 non-null    int64
#  1    artistname  459 non-null    object
#  2    song_name   459 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 10.9+ KB

# %%
df.shape
# Out:
# (459, 3)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Tus credenciales de la aplicación de Spotify
client_id = '451aa62bae54460285deb9a8a0921675'
client_secret = '4c31e871561a4aaeabf7e2c183504e47'

# Autenticación
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
df.columns = df.columns.str.strip()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Tus credenciales de la aplicación de Spotify
client_id = '451aa62bae54460285deb9a8a0921675'
client_secret = '4c31e871561a4aaeabf7e2c183504e47'

# Autenticación
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# Definir una función para obtener la información de una canción
def get_song_info(song_name):
    results = sp.search(q=song_name, limit=1)
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        artist_id = track['artists'][0]['id']
        artist_info = sp.artist(artist_id)
        genres = artist_info['genres'] if artist_info['genres'] else ['Not Available']

        album_id = track['album']['id']
        album_info = sp.album(album_id)
        album_name = album_info['name']
        album_release_date = album_info['release_date']

        duration_ms = track['duration_ms']
        minutes = duration_ms // 60000
        seconds = (duration_ms % 60000) // 1000
        duration_formatted = f"{minutes} min {seconds} s"

        song_info = {
            'song_name': track['name'],
            'artist': track['artists'][0]['name'],
            'genre': ', '.join(genres),
            'popularity': track['popularity'],
            'album_name': album_name,
            'album_release_date': album_release_date,
            'duration': duration_formatted
        }
        return song_info
    else:
        return None

# %%
# Obtener información de todas las canciones en el DataFrame
column_name = 'song_name'
df.columns = df.columns.str.strip()
song_infos = [get_song_info(song) for song in df[column_name]]

# Filtrar los valores None
song_infos = [info for info in song_infos if info is not None]

# Convertir a DataFrame para análisis
song_info_df = pd.DataFrame(song_infos)
print(song_info_df.head())
# Out:
#                                            song_name  \
# 0               (The Angels Wanna Wear My) Red Shoes
# 1  (What's So Funny 'Bout) Peace, Love And Unders...
# 2                                             Take 7
# 3                              Accidents Will Happen
# 4                                             Alison
#
#                              artist  \
# 0                    Elvis Costello
# 1  Elvis Costello & The Attractions
# 2                 10 Years Too Late
# 3  Elvis Costello & The Attractions
# 4                          Slowdive
#
#                                                genre  popularity  \
# 0  new wave, new wave pop, permanent wave, power ...          33
# 1  art rock, new romantic, new wave, new wave pop...          36
# 2                                      Not Available           0
# 3  art rock, new romantic, new wave, new wave pop...          32
# 4  alternative rock, dream pop, reading indie, sh...          56
#
#                             album_name album_release_date    duration
# 0                       My Aim Is True         1977-07-22  2 min 47 s
# 1  Armed Forces (Super Deluxe Edition)         1979-01-05  3 min 31 s
# 2                  Sounds from Nowhere               2002  2 min 50 s
# 3  Armed Forces (Super Deluxe Edition)         1979-01-05   3 min 1 s
# 4                             Souvlaki               1993  3 min 50 s

# %%
# Imprimir la información de las canciones
for index, row in song_info_df.iterrows():
    print(f"Usuario: {df.iloc[index]['user_id']}")
    print(f"Canción: {row['song_name']}")
    print(f"Artista: {row['artist']}")
    print(f"Género: {row['genre']}")
    print(f"Popularidad: {row['popularity']}")
    print(f"Álbum: {row['album_name']}")
    print(f"Fecha de lanzamiento del álbum: {row['album_release_date']}")
    print(f"Duración: {row['duration']} segundos\n")
# Out:
# Usuario: 1
# Canción: (The Angels Wanna Wear My) Red Shoes
# Artista: Elvis Costello
# Género: new wave, new wave pop, permanent wave, power pop, singer-songwriter
# Popularidad: 33
# Álbum: My Aim Is True
# Fecha de lanzamiento del álbum: 1977-07-22
# Duración: 2 min 47 s segundos
#
# Usuario: 1
# Canción: (What's So Funny 'Bout) Peace, Love And Understanding
# Artista: Elvis Costello & The Attractions
# Género: art rock, new romantic, new wave, new wave pop, power pop
# Popularidad: 36
# Álbum: Armed Forces (Super Deluxe Edition)
# Fecha de lanzamiento del álbum: 1979-01-05
# Duración: 3 min 31 s segundos
#
# Usuario: 1
# Canción: Take 7
# Artista: 10 Years Too Late
# Género: Not Available
# Popularidad: 0
# Álbum: Sounds from Nowhere
# Fecha de lanzamiento del álbum: 2002
# Duración: 2 min 50 s segundos
#
# Usuario: 1
# Canción: Accidents Will Happen
# Artista: Elvis Costello & The Attractions
# Género: art rock, new romantic, new wave, new wave pop, power pop
# Popularidad: 32
# Álbum: Armed Forces (Super Deluxe Edition)
# Fecha de lanzamiento del álbum: 1979-01-05
# Duración: 3 min 1 s segundos
#
# Usuario: 1
# Canción: Alison
# Artista: Slowdive
# Género: alternative rock, dream pop, reading indie, shoegaze
# Popularidad: 56
# Álbum: Souvlaki
# Fecha de lanzamiento del álbum: 1993
# Duración: 3 min 50 s segundos
#
# Usuario: 1
# Canción: Begin
# Artista: Shallou
# Género: electropop, indie electropop, vapor soul
# Popularidad: 56
# Álbum: All Becomes Okay
# Fecha de lanzamiento del álbum: 2017-05-12
# Duración: 4 min 2 s segundos
#
# Usuario: 1
# Canción: Band On The Run - 2010 Remaster
# Artista: Paul McCartney
# Género: classic rock, mellow gold, rock, soft rock
# Popularidad: 66
# Álbum: Band On The Run (Standard)
# Fecha de lanzamiento del álbum: 1973-12-05
# Duración: 5 min 13 s segundos
#
# Usuario: 1
# Canción: Beautiful Things
# Artista: Benson Boone
# Género: singer-songwriter pop
# Popularidad: 88
# Álbum: Beautiful Things
# Fecha de lanzamiento del álbum: 2024-01-18
# Duración: 3 min 0 s segundos
#
# Usuario: 1
# Canción: Blackbird
# Artista: Sarah McLachlan
# Género: canadian pop, canadian singer-songwriter, ectofolk, lilith, permanent wave, pop rock
# Popularidad: 48
# Álbum: Rarities, B-Sides and Other Stuff, Volume 2
# Fecha de lanzamiento del álbum: 2008-04-14
# Duración: 2 min 21 s segundos
#
# Usuario: 1
# Canción: Bright Side of the Road
# Artista: Van Morrison
# Género: classic rock, folk, folk rock, mellow gold, rock, singer-songwriter, soft rock
# Popularidad: 55
# Álbum: Into the Music
# Fecha de lanzamiento del álbum: 1979-08
# Duración: 3 min 46 s segundos
#
# Usuario: 1
# Canción: I Bet You Look Good On The Dancefloor
# Artista: Arctic Monkeys
# Género: garage rock, modern rock, permanent wave, rock, sheffield indie
# Popularidad: 68
# Álbum: Whatever People Say I Am, That's What I'm Not
# Fecha de lanzamiento del álbum: 2006-01-29
# Duración: 2 min 53 s segundos
#
# Usuario: 1
# Artista: Staind
# Género: alternative metal, nu metal, post-grunge
# Popularidad: 47
# Álbum: 14 Shades of Grey
# Fecha de lanzamiento del álbum: 2003-05-13
# Duración: 4 min 36 s segundos
#
# Usuario: 2
# Canción: Zombie
# Artista: The Cranberries
# Género: irish rock, pop rock, rock
# Popularidad: 78
# Álbum: No Need To Argue (The Complete Sessions 1994-1995)
# Fecha de lanzamiento del álbum: 1994-10-03
# Duración: 5 min 6 s segundos
#
# Usuario: 2
# Canción: Black Meteorite
# Artista: FelMax
# Género: traprun
# Popularidad: 19
# Álbum: Subsidia: Night Vol. 8
# Fecha de lanzamiento del álbum: 2023-04-19
# Duración: 2 min 14 s segundos
#
# Usuario: 2
# Canción: Burnin' / Too Long
# Artista: Daft Punk
# Género: electro, filter house, rock
# Popularidad: 40
# Álbum: Alive 2007
# Fecha de lanzamiento del álbum: 2007-11-19
# Duración: 7 min 11 s segundos
#
# Usuario: 2
# Canción: C.L.U.
# Artista: Daft Punk
# Género: electro, filter house, rock
# Popularidad: 37
# Álbum: TRON: Legacy - The Complete Edition (Original Motion Picture Soundtrack)
# Fecha de lanzamiento del álbum: 2010-12-03
# Duración: 4 min 39 s segundos
#
# Usuario: 2
# Canción: C.L.U. - Remixed by Paul Oakenfold
# Artista: Daft Punk
# Género: electro, filter house, rock
# Popularidad: 28
# Álbum: TRON: Legacy Reconfigured
# Fecha de lanzamiento del álbum: 2011-01-01
# Duración: 4 min 35 s segundos
#
# Usuario: 2
# Canción: Crescendolls
# Artista: Daft Punk
# Género: electro, filter house, rock
# Popularidad: 50
# Álbum: Discovery
# Fecha de lanzamiento del álbum: 2001-03-12
# Duración: 3 min 31 s segundos
#
# Usuario: 3
# Canción: One (Remastered)
# Artista: Metallica
# Género: hard rock, metal, old school thrash, rock, thrash metal
# Popularidad: 64
# Álbum: ...And Justice for All (Remastered Deluxe Box Set)
# Fecha de lanzamiento del álbum: 1988-09-07
# Duración: 7 min 26 s segundos
#
# Usuario: 3
# Canción: Photograph
# Artista: Ed Sheeran
# Género: pop, singer-songwriter pop, uk pop
# Popularidad: 77
# Álbum: x (Deluxe Edition)
# Fecha de lanzamiento del álbum: 2014-06-21
# Duración: 4 min 18 s segundos
#
# Usuario: 3
# Canción: Riding to New York
# Artista: Passenger
# Género: folk-pop, neo mellow
# Popularidad: 18
# Álbum: Whispers (Deluxe)
# Fecha de lanzamiento del álbum: 2014-06-10
# Duración: 5 min 2 s segundos
#
# Usuario: 3
# Canción: ROLLING STONE
# Artista: Brent Faiyaz
# Género: r&b, rap
# Popularidad: 66
# Álbum: WASTELAND
# Fecha de lanzamiento del álbum: 2022-07-08
# Duración: 2 min 42 s segundos
#
# Usuario: 3
# Canción: Romantic Type
# Artista: The Pigeon Detectives
# Género: british indie rock, britpop, english indie rock, leeds indie
# Popularidad: 29
# Álbum: Wait for Me
# Fecha de lanzamiento del álbum: 2007-05-27
# Duración: 2 min 37 s segundos
#
# Usuario: 3
# Canción: Runaway
# Artista: AURORA
# Género: art pop, norwegian pop
# Popularidad: 66
# Álbum: All My Demons Greeting Me as a Friend (Deluxe)
# Fecha de lanzamiento del álbum: 2014
# Duración: 4 min 8 s segundos
#
# Usuario: 3
# Canción: Scare Away the Dark
# Artista: Passenger
# Género: folk-pop, neo mellow
# Popularidad: 24
# Álbum: Whispers (Deluxe)
# Fecha de lanzamiento del álbum: 2014-06-10
# Duración: 4 min 38 s segundos
#
# Usuario: 3
# Canción: Shirtsleeves
# Artista: Ed Sheeran
# Género: pop, singer-songwriter pop, uk pop
# Popularidad: 44
# Álbum: x (Deluxe Edition)
# Fecha de lanzamiento del álbum: 2014-06-21
# Duración: 3 min 10 s segundos
#
# Usuario: 3
# Canción: Sing For The Moment
# Artista: Eminem
# Género: detroit hip hop, hip hop, rap
# Popularidad: 71
# Álbum: The Eminem Show
# Fecha de lanzamiento del álbum: 2002-05-26
# Duración: 5 min 39 s segundos
#
# Usuario: 3
# Canción: Start a Fire
# Artista: Unspoken
# Género: ccm, christian alternative rock, christian music
# Popularidad: 49
# Álbum: Unspoken
# Fecha de lanzamiento del álbum: 2014-04-01
# Duración: 3 min 4 s segundos
#
# Usuario: 3
# Canción: Summertime Sadness
# Artista: Lana Del Rey
# Género: art pop, pop
# Popularidad: 62
# Álbum: Born To Die - The Paradise Edition
# Fecha de lanzamiento del álbum: 2012-11-12
# Duración: 4 min 25 s segundos
#
# Usuario: 3
# Canción: Sweeter Than Fiction - From "One Chance" Soundtrack
# Artista: Taylor Swift
# Género: pop
# Popularidad: 48
# Álbum: Sweeter Than Fiction
# Fecha de lanzamiento del álbum: 2013-10-21
# Duración: 3 min 57 s segundos
#
# Usuario: 3
# Canción: Take It Back
# Artista: Marshmello
# Género: brostep, edm, pop, progressive electro house
# Popularidad: 37
# Álbum: Joytime
# Fecha de lanzamiento del álbum: 2016-01-08
# Duración: 3 min 53 s segundos
#
# Usuario: 3
# Canción: Tenerife Sea
# Artista: Ed Sheeran
# Género: pop, singer-songwriter pop, uk pop
# Popularidad: 60
# Álbum: x (Deluxe Edition)
# Fecha de lanzamiento del álbum: 2014-06-21
# Duración: 4 min 1 s segundos
#
# Usuario: 3
# Canción: The Man
# Artista: Taylor Swift
# Género: pop
# Popularidad: 76
# Álbum: Lover
# Fecha de lanzamiento del álbum: 2019-08-23
# Duración: 3 min 10 s segundos
#
# Usuario: 4
# Canción: 7 Things
# Artista: Miley Cyrus
# Género: pop
# Popularidad: 25
# Álbum: 2000's Pop Hits
# Fecha de lanzamiento del álbum: 2020-07-03
# Duración: 3 min 33 s segundos
#
# Usuario: 4
# Canción: A Love Like War (feat. Vic Fuentes)
# Artista: All Time Low
# Género: modern rock, neon pop punk, pop emo, pop punk
# Popularidad: 51
# Álbum: Don't Panic: It's Longer Now!
# Fecha de lanzamiento del álbum: 2013-09-30
# Duración: 3 min 33 s segundos
#
# Usuario: 4
# Canción: Song About Me
# Artista: TV Girl
# Género: pov: indie
# Popularidad: 62
# Álbum: Who Really Cares
# Fecha de lanzamiento del álbum: 2016-02-25
# Duración: 4 min 3 s segundos
#
# Usuario: 4
# Canción: All Star
# Artista: Smash Mouth
# Género: pop rock, post-grunge
# Popularidad: 75
# Álbum: Astro Lounge
# Fecha de lanzamiento del álbum: 1999-06-08
# Duración: 3 min 20 s segundos
#
# Usuario: 4
# Canción: All That Matters
# Artista: Justin Bieber
# Género: canadian pop, pop
# Popularidad: 48
# Álbum: Journals
# Fecha de lanzamiento del álbum: 2014-05-13
# Duración: 3 min 11 s segundos
#
# Usuario: 4
# Canción: Amnesia
# Artista: La Santa Grifa
# Género: mexican hip hop, sad sierreno, tamaulipas rap
# Popularidad: 67
# Álbum: Amnesia
# Fecha de lanzamiento del álbum: 2021-06-11
# Duración: 3 min 8 s segundos
#
# Usuario: 4
# Canción: Angel in Blue Jeans
# Artista: Train
# Género: dance pop, neo mellow, pop, pop rock
# Popularidad: 45
# Álbum: Bulletproof Picasso
# Fecha de lanzamiento del álbum: 2014-09-16
# Duración: 3 min 25 s segundos
#
# Usuario: 4
# Canción: Animals
# Artista: Maroon 5
# Género: pop
# Popularidad: 74
# Álbum: V
# Fecha de lanzamiento del álbum: 2014-09-02
# Duración: 3 min 51 s segundos
#
# Usuario: 4
# Canción: Bang Bang
# Artista: K'NAAN
# Género: reggae fusion
# Popularidad: 68
# Álbum: Troubadour
# Fecha de lanzamiento del álbum: 2009
# Duración: 3 min 6 s segundos
#
# Usuario: 4
# Canción: Bite My Tongue
# Artista: You Me At Six
# Género: modern alternative rock, modern rock, neon pop punk, pop emo, pop punk
# Popularidad: 21
# Álbum: Sinners Never Sleep (10 Year Anniversary Edition)
# Fecha de lanzamiento del álbum: 2022-05-27
# Duración: 3 min 42 s segundos
#
# Usuario: 4
# Canción: A Bitter Broken Memory
# Artista: Atreyu
# Género: alternative metal, melodic metalcore, metalcore, nu metal, post-grunge, screamo
# Popularidad: 23
# Álbum: Long Live
# Fecha de lanzamiento del álbum: 2015-09-18
# Duración: 3 min 58 s segundos
#
# Usuario: 4
# Canción: Break Your Little Heart
# Artista: All Time Low
# Género: modern rock, neon pop punk, pop emo, pop punk
# Popularidad: 50
# Álbum: Nothing Personal (Deluxe Version)
# Fecha de lanzamiento del álbum: 2009-07-07
# Duración: 2 min 51 s segundos
#
# Usuario: 4
# Canción: Breaking Up With God
# Artista: The Ark
# Género: classic swedish pop, swedish pop
# Popularidad: 26
# Álbum: It Takes A Fool To Remain Sane 2000 - 2011
# Fecha de lanzamiento del álbum: 2019-03-01
# Duración: 3 min 28 s segundos
#
# Usuario: 4
# Canción: Budapest
# Artista: George Ezra
# Género: folk-pop, neo-singer-songwriter
# Popularidad: 79
# Álbum: Wanted on Voyage (Expanded Edition)
# Fecha de lanzamiento del álbum: 2014-06-30
# Duración: 3 min 20 s segundos
#
# Usuario: 4
# Canción: Calleth You, Cometh I
# Artista: The Ark
# Género: classic swedish pop, swedish pop
# Popularidad: 37
# Álbum: In Lust We Trust
# Fecha de lanzamiento del álbum: 2002-08-26
# Duración: 4 min 32 s segundos
#
# Usuario: 5
# Canción: Center of the Universe - Radio Edit
# Artista: Axwell
# Género: dutch house, edm, electro house, pop dance, progressive electro house, progressive house
# Canción: Medicine - Radio Mix
# Artista: Kim Leoni
# Género: hands up
# Popularidad: 2
# Álbum: Best Dance Hits Ever Top 50 Volume 2
# Fecha de lanzamiento del álbum: 2019-08-02
# Duración: 2 min 47 s segundos
#
# Usuario: 7
# Canción: Private Number
# Artista: William Bell
# Género: memphis soul, southern soul
# Popularidad: 33
# Álbum: The Best Of William Bell
# Fecha de lanzamiento del álbum: 1990-01-01
# Duración: 2 min 40 s segundos
#
# Usuario: 7
# Canción: Smile - Luna Mix
# Artista: DJ Ross
# Género: italo dance
# Popularidad: 13
# Álbum: Smile
# Fecha de lanzamiento del álbum: 2003
# Duración: 5 min 16 s segundos
#
# Usuario: 7
# Canción: Walking in Memphis
# Artista: Marc Cohn
# Género: mellow gold
# Popularidad: 63
# Álbum: Marc Cohn
# Fecha de lanzamiento del álbum: 1991-02-08
# Duración: 4 min 12 s segundos
#
# Usuario: 7
# Canción: The Weekend Has Come - Neorin Remix Edit
# Artista: DJ Roxx
# Género: hands up
# Popularidad: 8
# Álbum: The Weekend Has Come
# Fecha de lanzamiento del álbum: 2010-01-29
# Duración: 3 min 29 s segundos
#
# Usuario: 7
# Canción: Rest Of Your Life (Da Tweekaz Remix) - Radio Edit
# Artista: Darren Styles
# Género: happy hardcore, hardcore techno
# Popularidad: 26
# Álbum: Rest Of Your Life (Da Tweekaz Remix)
# Fecha de lanzamiento del álbum: 2015-04-27
# Duración: 4 min 1 s segundos
#
# Usuario: 8
# Canción: Bailando - Spanish Version
# Artista: Enrique Iglesias
# Género: dance pop, latin pop, mexican pop
# Popularidad: 62
# Álbum: SEX AND LOVE (Deluxe)
# Fecha de lanzamiento del álbum: 2014-01-01
# Duración: 4 min 3 s segundos
#
# Usuario: 8
# Canción: Beautiful Things
# Artista: Benson Boone
# Género: singer-songwriter pop
# Popularidad: 88
# Álbum: Beautiful Things
# Fecha de lanzamiento del álbum: 2024-01-18
# Duración: 3 min 0 s segundos
#
# Usuario: 8
# Canción: El Perdedor
# Artista: Maluma
# Género: latin pop, reggaeton, reggaeton colombiano, trap latino, urbano latino
# Popularidad: 68
# Álbum: Pretty Boy, Dirty Boy
# Fecha de lanzamiento del álbum: 2015-10-30
# Duración: 3 min 26 s segundos
#
# Usuario: 8
# Canción: Finally Found You
# Artista: Enrique Iglesias
# Género: dance pop, latin pop, mexican pop
# Popularidad: 40
# Álbum: Finally Found You
# Fecha de lanzamiento del álbum: 2012-01-01
# Duración: 3 min 40 s segundos
#
# Usuario: 8
# Canción: Heart Attack
# Artista: Demi Lovato
# Género: pop, post-teen pop
# Popularidad: 74
# Álbum: Demi
# Fecha de lanzamiento del álbum: 2013-01-01
# Duración: 3 min 30 s segundos
#
# Usuario: 8
# Canción: Cercavo Amore
# Artista: Emma
# Género: italian adult pop, italian pop
# Popularidad: 22
# Álbum: TOP OF THE SPOT Musica & Pubblicità in TV 80's / 90's Vol.1
# Fecha de lanzamiento del álbum: 2021-03-19
# Duración: 3 min 32 s segundos
#
# Usuario: 8
# Canción: Ciencia Ficcion
# Artista: Leiva
# Género: cantautor, latin arena pop, spanish indie pop, spanish pop, spanish rock
# Popularidad: 37
# Álbum: Polvora
# Fecha de lanzamiento del álbum: 2014-01-31
# Duración: 4 min 31 s segundos
#
# Usuario: 8
# Canción: Del Hueso una Flor
# Artista: Leiva
# Género: cantautor, latin arena pop, spanish indie pop, spanish pop, spanish rock
# Popularidad: 24
# Álbum: Polvora
# Fecha de lanzamiento del álbum: 2014-01-31
# Duración: 3 min 57 s segundos
#
# Usuario: 8
# Canción: Francesita
# Artista: Dj Ghosty
# Género: circuit, gogeo, guaracha
# Popularidad: 44
# Álbum: Francesita
# Fecha de lanzamiento del álbum: 2018-07-23
# Duración: 6 min 18 s segundos
#
# Usuario: 8
# Canción: Hermosa Taquicardia
# Artista: Leiva
# Género: cantautor, latin arena pop, spanish indie pop, spanish pop, spanish rock
# Popularidad: 24
# Álbum: Polvora
# Fecha de lanzamiento del álbum: 2014-01-31
# Duración: 3 min 57 s segundos
#
# Usuario: 8
# Canción: El Venao
# Artista: Los Cantantes
# Género: tropical
# Popularidad: 50
# Álbum: El Virao
# Fecha de lanzamiento del álbum: 1995-06-01
# Duración: 4 min 52 s segundos
#
# Usuario: 8
# Canción: Act My Age
# Artista: One Direction
# Género: boy band, pop, post-teen pop, talent show
# Popularidad: 52
# Álbum: FOUR (Deluxe)
# Fecha de lanzamiento del álbum: 2014-11-17
# Duración: 3 min 18 s segundos
#
# Usuario: 8
# Canción: Alive
# Artista: Pearl Jam
# Género: alternative metal, alternative rock, classic rock, grunge, hard rock, permanent wave, rock
# Popularidad: 69
# Álbum: Ten
# Fecha de lanzamiento del álbum: 1991-08-27
# Duración: 5 min 40 s segundos
#
# Usuario: 8
# Canción: Another World
# Artista: Gojira
# Género: alternative metal, french death metal, french metal, groove metal, metal, nu metal, progressive groove metal
# Popularidad: 47
# Álbum: Fortitude
# Fecha de lanzamiento del álbum: 2021-04-30
# Duración: 4 min 24 s segundos
#
# Usuario: 8
# Canción: Back For You
# Artista: One Direction
# Género: boy band, pop, post-teen pop, talent show
# Popularidad: 50
# Álbum: Take Me Home (Expanded Edition)
# Fecha de lanzamiento del álbum: 2012-11-12
# Duración: 2 min 58 s segundos
#
# Usuario: 9
# Canción: Anything Could Happen
# Artista: Ellie Goulding
# Género: indietronica, metropopolis, pop, uk pop
# Popularidad: 50
# Álbum: Halcyon
# Fecha de lanzamiento del álbum: 2012-01-01
# Duración: 4 min 46 s segundos
#
# Usuario: 9
# Canción: Do You Mind (feat. Nicki Minaj, Chris Brown, August Alsina, Jeremih, Future & Rick Ross)
# Artista: DJ Khaled
# Género: hip hop, miami hip hop, pop rap, rap
# Popularidad: 48
# Álbum: Major Key
# Fecha de lanzamiento del álbum: 2016-08-05
# Duración: 5 min 25 s segundos
#
# Usuario: 9
# Canción: Kids
# Artista: MGMT
# Género: alternative rock, indie rock, indietronica, modern rock, rock
# Popularidad: 73
# Álbum: Oracular Spectacular
# Fecha de lanzamiento del álbum: 2007-12-14
# Duración: 5 min 2 s segundos
#
# Usuario: 9
# Canción: Simple As...
# Artista: Kid Cudi
# Género: hip hop, ohio hip hop, pop rap, rap
# Popularidad: 43
# Álbum: Man On The Moon: The End Of Day (Deluxe)
# Fecha de lanzamiento del álbum: 2009-01-01
# Duración: 2 min 31 s segundos
#
# Usuario: 9
# Canción: Why I Love You
# Artista: MAJOR.
# Género: pop soul
# Popularidad: 43
# Álbum: Why I Love You - Single
# Fecha de lanzamiento del álbum: 2016-05-21
# Duración: 3 min 55 s segundos
#
# Usuario: 9
# Canción: Blue Ocean Floor
# Artista: Justin Timberlake
# Género: dance pop, pop
# Popularidad: 37
# Álbum: The 20/20 Experience (Deluxe Version)
# Fecha de lanzamiento del álbum: 2013-03-15
# Duración: 7 min 19 s segundos
#
# Usuario: 9
# Canción: Dead and Gone (Made Famous by T.I. feat. Justin Timberlake)
# Artista: Top Hip Hop DJs
# Género: Not Available
# Popularidad: 0
# Álbum: 100 Hip Hop 2010 Hits
# Fecha de lanzamiento del álbum: 2010-09-01
# Duración: 5 min 0 s segundos
#
# Usuario: 9
# Canción: Don't Hold the Wall
# Artista: Justin Timberlake
# Género: dance pop, pop
# Popularidad: 39
# Álbum: The 20/20 Experience (Deluxe Version)
# Fecha de lanzamiento del álbum: 2013-03-15
# Duración: 7 min 10 s segundos
#
# Usuario: 9
# Canción: Let the Groove Get In
# Artista: Justin Timberlake
# Género: dance pop, pop
# Popularidad: 42
# Álbum: The 20/20 Experience (Deluxe Version)
# Fecha de lanzamiento del álbum: 2013-03-15
# Duración: 7 min 11 s segundos
#
# Usuario: 9
# Canción: Mirrors
# Artista: Justin Timberlake
# Género: dance pop, pop
# Popularidad: 74
# Álbum: The 20/20 Experience (Deluxe Version)
# Fecha de lanzamiento del álbum: 2013-03-15
# Duración: 8 min 4 s segundos
#
# Usuario: 9
# Canción: If I Lose Myself - Alesso vs OneRepublic
# Artista: OneRepublic
# Género: piano rock, pop
# Popularidad: 55
# Álbum: Native
# Fecha de lanzamiento del álbum: 2014-01-01
# Duración: 3 min 34 s segundos
#
# Usuario: 9
# Canción: Light It Up (Remix)
# Artista: Major Lazer
# Género: dance pop, edm, electro house, moombahton, pop, pop dance
# Popularidad: 63
# Álbum: Peace Is The Mission (Extended)
# Fecha de lanzamiento del álbum: 2015-11-27
# Duración: 2 min 46 s segundos
#
# Usuario: 9
# Canción: Little Boy and the Preacher Man
# Artista: Nu Breed
# Género: redneck
# Popularidad: 45
# Álbum: Outlaw Nation, Vol. 1
# Fecha de lanzamiento del álbum: 2021-03-05
# Duración: 3 min 45 s segundos
#
# Usuario: 9
# Canción: Something I Need
# Artista: OneRepublic
# Género: piano rock, pop
# Popularidad: 52
# Álbum: Native
# Fecha de lanzamiento del álbum: 2013-01-01
# Duración: 4 min 0 s segundos
#
# Usuario: 9
# Canción: What You Wanted
# Artista: Shinedown
# Género: alternative metal, nu metal, post-grunge
# Popularidad: 36
# Álbum: Planet Zero
# Fecha de lanzamiento del álbum: 2022-07-01
# Duración: 3 min 3 s segundos
#
# Usuario: 10
# Canción: 1901
# Artista: Phoenix
# Género: alternative dance, indie rock, modern rock, neo-synthpop, new rave, rock independant francais, shimmer pop
# Popularidad: 67
# Álbum: Wolfgang Amadeus Phoenix
# Fecha de lanzamiento del álbum: 2009-05-25
# Duración: 3 min 13 s segundos
#
# Usuario: 10
# Canción: All My Stars Aligned
# Artista: St. Vincent
# Género: art pop, etherpop, indie rock, indietronica, metropopolis, neo-synthpop
# Popularidad: 22
# Álbum: Marry Me
# Fecha de lanzamiento del álbum: 2007-07-10
# Duración: 3 min 47 s segundos
#
# Usuario: 10
# Canción: Come On Home - Chewy Rubs Bump It Deep Extended Mix
# Artista: Dion's House Kitchen
# Género: Not Available
# Popularidad: 1
# Álbum: Come On Home
# Fecha de lanzamiento del álbum: 2024-05-03
# Duración: 7 min 0 s segundos
#
# Usuario: 10
# Canción: Disenchanted
# Artista: My Chemical Romance
# Género: emo, modern rock, pop punk, pov: indie, rock
# Popularidad: 67
# Álbum: The Black Parade
# Fecha de lanzamiento del álbum: 2006-10-23
# Duración: 4 min 55 s segundos
#
# Usuario: 10
# Canción: Dream A Little Dream Of Me
# Artista: The Mamas & The Papas
# Género: classic rock, folk, folk rock, mellow gold, psychedelic rock, rock, soft rock, sunshine pop
# Popularidad: 69
# Álbum: The Papas & The Mamas
# Fecha de lanzamiento del álbum: 1968-05-01
# Duración: 3 min 14 s segundos
#
# Usuario: 10
# Canción: Good Thing (with Kehlani)
# Artista: Zedd
# Género: complextro, edm, german techno, pop, pop dance
# Popularidad: 57
# Álbum: Good Thing (with Kehlani)
# Fecha de lanzamiento del álbum: 2019-09-27
# Duración: 3 min 30 s segundos
#
# Usuario: 10
# Canción: Lightning Bolt
# Artista: Jake Bugg
# Género: nottingham indie
# Popularidad: 57
# Álbum: Jake Bugg
# Fecha de lanzamiento del álbum: 2012-01-01
# Duración: 2 min 24 s segundos
#
# Usuario: 10
# Canción: Make Believe
# Artista: Jakeneutron
# Género: otacore, pixel, rhythm game
# Popularidad: 37
# Álbum: Make Believe
# Fecha de lanzamiento del álbum: 2023-01-28
# Duración: 2 min 53 s segundos
#
# Usuario: 10
# Canción: older
# Artista: Isabel LaRosa
# Género: hyperpop, sped up
# Popularidad: 78
# Álbum: older
# Fecha de lanzamiento del álbum: 2023-09-15
# Duración: 2 min 17 s segundos
#
# Usuario: 10
# Canción: Paris Is Burning
# Artista: Ladyhawke
# Género: alternative dance, metropopolis, neo-synthpop
# Popularidad: 26
# Álbum: Ladyhawke
# Fecha de lanzamiento del álbum: 2008-01-01
# Duración: 3 min 49 s segundos
#
# Usuario: 10
# Canción: Pigeon
# Artista: Cavetown
# Género: bedroom pop, indie pop, pov: indie
# Popularidad: 43
# Álbum: Lemon Boy
# Fecha de lanzamiento del álbum: 2018-01-01
# Duración: 2 min 38 s segundos
#
# Usuario: 10
# Canción: Rosyln
# Artista: Bon Iver
# Género: chamber pop, eau claire indie, indie folk, melancholia, modern rock
# Popularidad: 69
# Álbum: The Twilight Saga: New Moon (Original Motion Picture Soundtrack)
# Fecha de lanzamiento del álbum: 2009-10-16
# Fecha de lanzamiento del álbum: 2009-11-02
# Duración: 3 min 58 s segundos
#
# Usuario: 11
# Canción: Daydreamin'
# Artista: Ariana Grande
# Género: pop
# Popularidad: 48
# Álbum: Yours Truly
# Fecha de lanzamiento del álbum: 2013-01-01
# Duración: 3 min 31 s segundos
#
# Usuario: 11
# Canción: Empty
# Artista: Juice WRLD
# Género: chicago rap, melodic rap, rap
# Popularidad: 67
# Álbum: Death Race For Love (Bonus Track Version)
# Fecha de lanzamiento del álbum: 2019-03-08
# Duración: 4 min 8 s segundos
#
# Usuario: 11
# Canción: Every Single Night
# Artista: Fiona Apple
# Género: art pop, chamber pop, dark pop, lilith, permanent wave, piano rock, singer-songwriter
# Popularidad: 42
# Álbum: The Idler Wheel Is Wiser Than the Driver of the Screw and Whipping Cords Will Serve You More Than Ropes Will Ever Do (Expanded Edition)
# Fecha de lanzamiento del álbum: 2012-06-18
# Duración: 3 min 29 s segundos
#
# Usuario: 11
# Canción: EVIL EMPIRE (feat. DD Osama)
# Artista: Lil Mabu
# Género: Not Available
# Popularidad: 60
# Álbum: YOUNG GENIUS
# Fecha de lanzamiento del álbum: 2024-04-05
# Duración: 2 min 59 s segundos
#
# Usuario: 11
# Canción: Faster n Harder
# Artista: 6arelyhuman
# Género: krushclub, scenecore
# Popularidad: 70
# Álbum: Faster n Harder
# Fecha de lanzamiento del álbum: 2024-02-28
# Duración: 2 min 3 s segundos
#
# Usuario: 11
# Canción: Feelin' The Same Way
# Artista: Norah Jones
# Género: contemporary vocal jazz, jazz pop, neo mellow, vocal jazz
# Popularidad: 56
# Álbum: Come Away With Me (Super Deluxe Edition)
# Fecha de lanzamiento del álbum: 2002-02-26
# Duración: 2 min 57 s segundos
#
# Usuario: 12
# Canción: Cuppa Joe
# Artista: Bellevue Cadillac
# Género: swing revival
# Popularidad: 0
# Álbum: The Best of Bellevue Cadillac: 20 Years of Swing!
# Fecha de lanzamiento del álbum: 2013-11-12
# Duración: 3 min 6 s segundos
#
# Usuario: 12
# Canción: More Than Anything
# Artista: Jeremy Jordan
# Género: show tunes
# Popularidad: 66
# Álbum: Hazbin Hotel (Original Soundtrack)
# Fecha de lanzamiento del álbum: 2024-02-02
# Duración: 3 min 13 s segundos
#
# Usuario: 12
# Canción: Blue Bolivar Blues - Take 2
# Artista: Thelonious Monk
# Género: bebop, contemporary post-bop, jazz, jazz piano, jazz trio
# Popularidad: 22
# Álbum: Monk's Dream
# Fecha de lanzamiento del álbum: 1963
# Duración: 7 min 30 s segundos
#
# Usuario: 12
# Canción: Eat, Sleep, Wake (Nothing But You)
# Artista: Bombay Bicycle Club
# Género: british indie rock, chamber pop, indie rock, indietronica, modern rock, shimmer pop
# Popularidad: 51
# Álbum: Everything Else Has Gone Wrong
# Fecha de lanzamiento del álbum: 2020-01-17
# Duración: 3 min 39 s segundos
#
# Usuario: 12
# Canción: Fever To The Form
# Artista: Nick Mulvey
# Género: british singer-songwriter, cambridgeshire indie, indie folk
# Popularidad: 60
# Álbum: First Mind
# Fecha de lanzamiento del álbum: 2014-05-12
# Fecha de lanzamiento del álbum: 2019-04-26
# Duración: 3 min 24 s segundos
#
# Usuario: 30
# Canción: Under Cover of Darkness
# Artista: The Strokes
# Género: alternative rock, garage rock, modern rock, permanent wave, rock
# Popularidad: 60
# Álbum: Angles
# Fecha de lanzamiento del álbum: 2011-03-21
# Duración: 3 min 55 s segundos
#
# Usuario: 30
# Canción: Under the stars
# Artista: Amélie Blumenthal
# Género: Not Available
# Popularidad: 54
# Álbum: Under the stars
# Fecha de lanzamiento del álbum: 2024-03-01
# Duración: 1 min 33 s segundos
#
# Usuario: 30
# Canción: Undercover Lover
# Artista: Three Plus
# Género: jawaiian
# Popularidad: 39
# Álbum: For You
# Fecha de lanzamiento del álbum: 2002-01-01
# Duración: 3 min 35 s segundos
#
# Usuario: 30
# Canción: Unforgetable
# Artista: Clark Younger
# Género: focus, piano cover
# Popularidad: 29
# Álbum: Clark Younger
# Fecha de lanzamiento del álbum: 2017-02-20
# Duración: 3 min 24 s segundos
#
# Usuario: 30
# Canción: Colors of the Wind
# Artista: Judy Kuhn
# Género: movie tunes
# Popularidad: 57
# Álbum: Pocahontas
# Fecha de lanzamiento del álbum: 1995-01-01
# Duración: 3 min 34 s segundos
#
# Usuario: 31
# Canción: Concrete Angel - Radio Edit
# Artista: Gareth Emery
# Género: edm, pop dance, progressive electro house, progressive house, trance
# Popularidad: 52
# Álbum: Concrete Angel
# Fecha de lanzamiento del álbum: 2012-02-13
# Duración: 3 min 55 s segundos
#
# Usuario: 31
# Canción: Dancing in the Fire - Radio Edit
# Artista: TOOMANYLEFTHANDS
# Género: danish electronic, scandipop
# Popularidad: 9
# Álbum: Dancing In The Fire
# Fecha de lanzamiento del álbum: 2014-01-31
# Duración: 3 min 26 s segundos
#
# Usuario: 31
# Canción: Alors on danse - Radio Edit
# Artista: Stromae
# Género: belgian pop, g-house
# Popularidad: 72
# Álbum: Cheese
# Fecha de lanzamiento del álbum: 2010-01-01
# Duración: 3 min 26 s segundos
#
# Usuario: 31
# Canción: Dare You (feat. Matthew Koma) - Cash Cash Remix
# Artista: Hardwell
# Género: big room, dutch house, edm, electro house, pop dance, progressive electro house, progressive house
# Popularidad: 8
# Álbum: Dare You (Remixes, Part 1) (feat. Matthew Koma)
# Fecha de lanzamiento del álbum: 2014-02-25
# Duración: 6 min 9 s segundos
#
# Usuario: 31
# Canción: Daylight - Radio Edit
# Artista: Disciples
# Género: house, pop dance, uk dance
# Popularidad: 33
# Álbum: Daylight (Remixes)
# Fecha de lanzamiento del álbum: 2016-10-07
# Duración: 2 min 49 s segundos
#
# Usuario: 31
# Canción: Echo
# Artista: XANU
# Género: Not Available
# Popularidad: 48
# Álbum: Echo
# Fecha de lanzamiento del álbum: 2024-04-05
# Duración: 2 min 22 s segundos
#
# Usuario: 31
# Canción: Faith - Radio Edit
# Artista: Blasterjaxx
# Género: big room, dutch house, edm, electro house, pop dance, progressive electro house, slap house
# Popularidad: 32
# Álbum: Faith (Radio Edit)
# Fecha de lanzamiento del álbum: 2014-02-18
# Género: jovem guarda, mpb
# Popularidad: 45
# Álbum: 30 Grandes Canciones
# Fecha de lanzamiento del álbum: 2000
# Duración: 3 min 51 s segundos
#
# Usuario: 32
# Canción: Es Mentiroso
# Artista: Olga Tañón
# Género: puerto rican pop, salsa, tropical
# Popularidad: 53
# Álbum: Siente El Amor
# Fecha de lanzamiento del álbum: 1994-10-18
# Duración: 4 min 2 s segundos
#
# Usuario: 32
# Canción: Dígale
# Artista: David Bisbal
# Género: latin arena pop, latin pop, spanish pop rock
# Popularidad: 67
# Álbum: Corazon Latino
# Fecha de lanzamiento del álbum: 2002-01-01
# Duración: 4 min 22 s segundos
#
# Usuario: 32
# Canción: Escapémonos - Salsa Version
# Artista: Marc Anthony
# Género: latin pop, modern salsa, salsa, tropical
# Popularidad: 38
# Álbum: Valio La Pena
# Fecha de lanzamiento del álbum: 2004-07-27
# Duración: 5 min 31 s segundos
#
# Usuario: 32
# Canción: Fruta Fresca
# Artista: Carlos Vives
# Género: colombian pop, latin pop, vallenato
# Popularidad: 56
# Álbum: El Amor De Mi Tierra
# Fecha de lanzamiento del álbum: 1999-01-01
# Duración: 3 min 53 s segundos
#
# Usuario: 32
# Canción: Hasta Que Salga El Sol
# Artista: Banda Los Recoditos
# Género: banda, banda sinaloense, musica mexicana, norteno
# Popularidad: 51
# Álbum: Sueño XXX
# Fecha de lanzamiento del álbum: 2014-09-02
# Duración: 2 min 23 s segundos
#
# Usuario: 32
# Canción: Idilio
# Artista: Willie Colón
# Género: salsa, tropical
# Popularidad: 64
# Álbum: Mis Favoritas
# Fecha de lanzamiento del álbum: 2010-06-08
# Duración: 5 min 8 s segundos
#
# Usuario: 32
# Canción: Juliana
# Artista: DLG
# Género: salsa, tropical
# Popularidad: 41
# Álbum: Lo Esencial
# Fecha de lanzamiento del álbum: 2000-07-11
# Duración: 4 min 56 s segundos
#
# Usuario: 32
# Canción: La Bamba - Single Version
# Artista: Ritchie Valens
# Género: rock-and-roll, rockabilly
# Popularidad: 61
# Álbum: Ritchie Valens
# Fecha de lanzamiento del álbum: 1959
# Duración: 2 min 6 s segundos
#
# Usuario: 32
# Canción: La Bomba
# Artista: Azul Azul
# Género: latin pop, pop boliviano
# Popularidad: 59
# Álbum: El Sapo
# Fecha de lanzamiento del álbum: 2000
# Duración: 2 min 3 s segundos
#
# Usuario: 32
# Canción: La Camisa Negra
# Artista: Juanes
# Género: colombian pop, latin pop, mexican pop, rock en espanol
# Popularidad: 67
# Álbum: Mi Sangre
# Fecha de lanzamiento del álbum: 2004-01-01
# Duración: 3 min 36 s segundos
#
# Usuario: 32
# Canción: La Negra Tiene Tumbao
# Artista: Celia Cruz
# Género: cha-cha-cha, cuban rumba, mambo, musica tradicional cubana, salsa
# Popularidad: 50
# Álbum: La Negra Tiene Tumbao
# Fecha de lanzamiento del álbum: 2001-12-03
# Duración: 4 min 13 s segundos
#
# Usuario: 32
# Canción: La Paga
# Artista: Juanes
# Género: colombian pop, latin pop, mexican pop, rock en espanol
# Popularidad: 52
# Álbum: Un Día Normal
# Fecha de lanzamiento del álbum: 2002-01-01
# Duración: 3 min 25 s segundos
#
# Usuario: 32
# Canción: La Travesia
# Artista: Juan Luis Guerra 4.40
# Género: bachata, latin pop, tropical
# Popularidad: 45
# Álbum: La Llave De Mi Corazon
# Fecha de lanzamiento del álbum: 2007-01-01
# Duración: 3 min 25 s segundos
#
# Usuario: 32
# Canción: La Ventanita
# Artista: Sergio Vargas
# Género: merengue, tropical
# Popularidad: 53
# Álbum: Coleccion de Oro
# Fecha de lanzamiento del álbum: 2002-06-18
# Duración: 4 min 46 s segundos
#
# Usuario: 32
# Canción: La Vida Es Un Carnaval
# Artista: Celia Cruz
# Género: cha-cha-cha, cuban rumba, mambo, musica tradicional cubana, salsa
# Popularidad: 64
# Álbum: Para La Eternidad
# Fecha de lanzamiento del álbum: 2016-05-27
# Duración: 4 min 38 s segundos
#
# Usuario: 32
# Canción: Lambada - Original Version 1989
# Artista: Kaoma
# Género: zouk
# Popularidad: 64
# Álbum: Lambada - Les originaux No. 1 de l'été (Original 1989)
# Fecha de lanzamiento del álbum: 1989-01-01
# Duración: 3 min 27 s segundos
#
# Usuario: 32
# Canción: Lamento Boliviano
# Artista: Los Enanitos Verdes
# Género: argentine rock, latin alternative, latin pop, latin rock, mexican pop, rock en espanol, ska argentino
# Popularidad: 74
# Álbum: Big Bang
# Fecha de lanzamiento del álbum: 1994-01-01
# Duración: 3 min 42 s segundos
#
# Usuario: 32
# Canción: Lamento Borincano - Salsa Version
# Artista: Marc Anthony
# Género: latin pop, modern salsa, salsa, tropical
# Popularidad: 30
# Álbum: Valio La Pena
# Fecha de lanzamiento del álbum: 2004-07-27
# Duración: 5 min 5 s segundos

# %% [markdown]
# # **Análisis de Preferencias Musicales: Identifiquen patrones en las preferenciasmusicales de los usuarios, como géneros favoritos, artistas populares, tendencias temporales.**

# %% [markdown]
# **Funcion por Usuario individual**

# %%
#Funcion anterior pero elijiendo el numero de usuario
# Configurar las credenciales de Spotify
client_id = '451aa62bae54460285deb9a8a0921675'
client_secret = '4c31e871561a4aaeabf7e2c183504e47'

# Autenticación
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

def get_song_info(song_name):
    results = sp.search(q=song_name, limit=1)
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        artist_id = track['artists'][0]['id']
        album_id = track['album']['id']

        # Información del artista
        artist_info = sp.artist(artist_id)
        genres = artist_info['genres'] if artist_info['genres'] else ['Not Available']

        # Información del álbum
        album_info = sp.album(album_id)
        album_name = album_info['name']
        album_release_date = album_info['release_date']

        duration_ms = track['duration_ms']
        minutes = duration_ms // 60000
        seconds = (duration_ms % 60000) // 1000
        duration_formatted = f"{minutes} min {seconds} s"

        song_info = {
            'song_name': track['name'],
            'artist': track['artists'][0]['name'],
            'genre': ', '.join(genres),
            'popularity': track['popularity'],
            'duration': duration_formatted,
            'album_name': album_name,
            'album_release_date': album_release_date
        }
        return song_info
    else:
        return None

# %%
#Funcion anterior pero generando un csv
def get_user_song_info(user_id):
    # Cargar el archivo CSV
    df = pd.read_csv('/content/spotify_dataset.csv')

    # Limpiar los nombres de las columnas eliminando espacios iniciales y finales
    df.columns = df.columns.str.strip()

    # Filtrar las canciones por el ID del usuario
    user_songs = df[df['user_id'] == user_id]['song_name']

    # Obtener información de todas las canciones del usuario
    song_infos = [get_song_info(song) for song in user_songs]

    # Filtrar los valores None
    song_infos = [info for info in song_infos if info is not None]

    # Convertir a DataFrame para análisis
    song_info_df = pd.DataFrame(song_infos)

    # Guardar el DataFrame en un archivo CSV
    output_csv = f'/content/song_info_user_{user_id}.csv'
    song_info_df.to_csv(output_csv, index=False)

    return song_info_df, output_csv

def get_favorite_artists_genres(song_info_df):
    artist_counts = song_info_df['artist'].value_counts()
    genre_counts = song_info_df['genre'].str.split(', ').explode().value_counts()
    return artist_counts, genre_counts

# %%
#Funcion anterior pero haciendo un print y count de sus gustos favoritos
user_id = 27
#song_info_df, output_csv = get_user_song_info(user_id)
print(f"Información de las canciones del usuario {user_id}  ")

# Contar los artistas y géneros favoritos
favorite_artists, favorite_genres = get_favorite_artists_genres(song_info_df)
print("\nArtistas favoritos:")
print(favorite_artists)
print("\nGéneros favoritos:")
print(favorite_genres)
# Out:
# Información de las canciones del usuario 27
#
# Artistas favoritos:
# artist
# JAY-Z                  8
# Taylor Swift           8
# Melendi                5
# Black Eyed Peas        5
# Avicii                 5
#                       ..
# NATTI NATASHA          1
# Sub Urban              1
# The Chainsmokers       1
# Speechwriters LLC      1
# Los Enanitos Verdes    1
# Name: count, Length: 348, dtype: int64
#
# Géneros favoritos:
# genre
# pop                 85
# rap                 42
# hip hop             42
# dance pop           41
# rock                40
#                     ..
# vintage jazz         1
# seattle indie        1
# modern indie pop     1
# rap latina           1
# ska argentino        1
# Name: count, Length: 401, dtype: int64

# %% [markdown]
# **Funcion para todos los usuarios**

# %%
def get_favorite_artists_genres(song_info_df, user_id):
    artist_counts = song_info_df['artist'].value_counts().reset_index()
    artist_counts.columns = ['name', 'count']
    artist_counts['type'] = 'artist'
    artist_counts['user_id'] = user_id

    genre_counts = song_info_df['genre'].str.split(', ').explode().value_counts().reset_index()
    genre_counts.columns = ['name', 'count']
    genre_counts['type'] = 'genre'
    genre_counts['user_id'] = user_id

    return artist_counts, genre_counts
# Cargar el archivo CSV
df = pd.read_csv('/content/spotify_dataset.csv')
# Limpiar los nombres de las columnas eliminando espacios iniciales y finales
df.columns = df.columns.str.strip()
# Obtener la lista de usuarios únicos
user_ids = df['user_id'].unique()
all_favorites = pd.DataFrame()
# Procesar información para todos los usuarios
for user_id in user_ids:
    song_info_df, _ = get_user_song_info(user_id)  # Fix the line here
    print(f"Información de las canciones del usuario {user_id} procesada.")
    # Contar los artistas y géneros favoritos y guardarlos en el DataFrame consolidado
    favorite_artists, favorite_genres = get_favorite_artists_genres(song_info_df, user_id)
    print("\nArtistas favoritos:")
    print(favorite_artists)
    print("\nGéneros favoritos:")
    print(favorite_genres)

    all_favorites = pd.concat([all_favorites, favorite_artists, favorite_genres], ignore_index=True)

# Guardar todos los artistas y géneros favoritos en un solo archivo CSV
all_favorites.to_csv('/content/all_favorites.csv', index=False)
print("Artistas y géneros favoritos de todos los usuarios guardados en all_favorites.csv.")
# Out:
# Información de las canciones del usuario 1 procesada.
#
# Artistas favoritos:
#                                 name  count    type  user_id
# 0   Elvis Costello & The Attractions      2  artist        1
# 1                     Elvis Costello      1  artist        1
# 2                  10 Years Too Late      1  artist        1
# 3                           Slowdive      1  artist        1
# 4                            Shallou      1  artist        1
# 5                     Paul McCartney      1  artist        1
# 6                       Benson Boone      1  artist        1
# 7                    Sarah McLachlan      1  artist        1
# 8                       Van Morrison      1  artist        1
# 9                     Arctic Monkeys      1  artist        1
# 10                        Lucy Pearl      1  artist        1
# 11                        Jonah Love      1  artist        1
# 12                     Crowded House      1  artist        1
# 13                  Hollywood Undead      1  artist        1
#
# Géneros favoritos:
#                           name  count   type  user_id
# 0               permanent wave      4  genre        1
# 1                     new wave      3  genre        1
# 2                    power pop      3  genre        1
# 3                 new wave pop      3  genre        1
# 4                         rock      3  genre        1
# 5                 classic rock      2  genre        1
# 6            singer-songwriter      2  genre        1
# 7                     art rock      2  genre        1
# 8                 new romantic      2  genre        1
# 9                Not Available      2  genre        1
# 10                 modern rock      2  genre        1
# 11                   soft rock      2  genre        1
# 12                 mellow gold      2  genre        1
# 13                 garage rock      1  genre        1
# 14             sheffield indie      1  genre        1
# 15              new jack swing      1  genre        1
# 16            contemporary r&b      1  genre        1
# 17                    neo soul      1  genre        1
# 18                        folk      1  genre        1
# 19             australian rock      1  genre        1
# 20           alternative metal      1  genre        1
# 21                 post-grunge      1  genre        1
# 22                   rap metal      1  genre        1
# 23                   folk rock      1  genre        1
# 24       singer-songwriter pop      1  genre        1
# 25                    pop rock      1  genre        1
# 26                      lilith      1  genre        1
# 27                    ectofolk      1  genre        1
# 28  canadian singer-songwriter      1  genre        1
# 29                canadian pop      1  genre        1
# 30                  vapor soul      1  genre        1
# 31            indie electropop      1  genre        1
# 32                  electropop      1  genre        1
# 33                    shoegaze      1  genre        1
# 34               reading indie      1  genre        1
# 35                   dream pop      1  genre        1
# 36            alternative rock      1  genre        1
# 37                    rap rock      1  genre        1
# Información de las canciones del usuario 2 procesada.
#
# Artistas favoritos:
#                    name  count    type  user_id
# 0             Daft Punk      4  artist        2
# 1       Jonny Henninger      1  artist        2
# 2            Andy Mineo      1  artist        2
# 3              Bon Jovi      1  artist        2
# 4        Cobra Starship      1  artist        2
# 5             The Kinks      1  artist        2
# 6         The Offspring      1  artist        2
# 7       Lennox Berkeley      1  artist        2
# 8   Taiko Drum Ensemble      1  artist        2
# 9                Staind      1  artist        2
# 10      The Cranberries      1  artist        2
# 11               FelMax      1  artist        2
#
# Géneros favoritos:
#                         name  count   type  user_id
# 0                       rock      8  genre        2
# 1               filter house      4  genre        2
# 2                    electro      4  genre        2
# 3          alternative metal      2  genre        2
# 4                post-grunge      2  genre        2
# 5                    traprun      1  genre        2
# 6                   pop rock      1  genre        2
# 7                 irish rock      1  genre        2
# 8                   nu metal      1  genre        2
# 9                      taiko      1  genre        2
# 10    early modern classical      1  genre        2
# 11  british modern classical      1  genre        2
# 12            socal pop punk      1  genre        2
# 13                skate punk      1  genre        2
# 14                      punk      1  genre        2
# 15            permanent wave      1  genre        2
# 16             christian pop      1  genre        2
# 17         christian hip hop      1  genre        2
# 18          psychedelic rock      1  genre        2
# 19                 protopunk      1  genre        2
# 20                 glam rock      1  genre        2
# 21                 folk rock      1  genre        2
# 22              classic rock      1  genre        2
# 23          british invasion      1  genre        2
# 24                  art rock      1  genre        2
# 25                album rock      1  genre        2
# 26             post-teen pop      1  genre        2
# 27                  pop punk      1  genre        2
# 28             neon pop punk      1  genre        2
# 29                glam metal      1  genre        2
# 30         singer-songwriter      1  genre        2
# Información de las canciones del usuario 3 procesada.
#
# Artistas favoritos:
#                      name  count    type  user_id
# 0              Ed Sheeran      3  artist        3
# 1               Passenger      2  artist        3
# 2            Taylor Swift      2  artist        3
# 3               Metallica      1  artist        3
# 4            Brent Faiyaz      1  artist        3
# 5   The Pigeon Detectives      1  artist        3
# 6                  AURORA      1  artist        3
# 7                  Eminem      1  artist        3
# 8                Unspoken      1  artist        3
# 9            Lana Del Rey      1  artist        3
# 10             Marshmello      1  artist        3
#
# Géneros favoritos:
#                           name  count   type  user_id
# 0                          pop      7  genre        3
# 1        singer-songwriter pop      3  genre        3
# 2                       uk pop      3  genre        3
# 3                      art pop      2  genre        3
# 4                     folk-pop      2  genre        3
# 5                   neo mellow      2  genre        3
# 6                          rap      2  genre        3
# 7                    hard rock      1  genre        3
# 8                          edm      1  genre        3
# 9                      brostep      1  genre        3
# 10             christian music      1  genre        3
# 11  christian alternative rock      1  genre        3
# 12                         ccm      1  genre        3
# 13                     hip hop      1  genre        3
# 14             detroit hip hop      1  genre        3
# 15               norwegian pop      1  genre        3
# 16                     britpop      1  genre        3
# 17                 leeds indie      1  genre        3
# 18          english indie rock      1  genre        3
# 19                       metal      1  genre        3
# 20          british indie rock      1  genre        3
# 21                         r&b      1  genre        3
# 22                thrash metal      1  genre        3
# 23                        rock      1  genre        3
# 24           old school thrash      1  genre        3
# 25   progressive electro house      1  genre        3
# Información de las canciones del usuario 4 procesada.
#
# Artistas favoritos:
#               name  count    type  user_id
# 0     All Time Low      2  artist        4
# 1          The Ark      2  artist        4
# 2      Miley Cyrus      1  artist        4
# 3          TV Girl      1  artist        4
# 4      Smash Mouth      1  artist        4
# 5    Justin Bieber      1  artist        4
# 6   La Santa Grifa      1  artist        4
# 7            Train      1  artist        4
# 8         Maroon 5      1  artist        4
# 9           K'NAAN      1  artist        4
# 10   You Me At Six      1  artist        4
# 11          Atreyu      1  artist        4
# 12     George Ezra      1  artist        4
#
# Géneros favoritos:
#                        name  count   type  user_id
# 0                       pop      4  genre        4
# 1             neon pop punk      3  genre        4
# 2                   pop emo      3  genre        4
# 3                  pop punk      3  genre        4
# 4               modern rock      3  genre        4
# 5                  pop rock      2  genre        4
# 6               post-grunge      2  genre        4
# 7               swedish pop      2  genre        4
# 8       classic swedish pop      2  genre        4
# 9         alternative metal      1  genre        4
# 10                 folk-pop      1  genre        4
# 11                  screamo      1  genre        4
# 12                 nu metal      1  genre        4
# 13                metalcore      1  genre        4
# 14        melodic metalcore      1  genre        4
# 15                dance pop      1  genre        4
# 16  modern alternative rock      1  genre        4
# 17            reggae fusion      1  genre        4
# 18               neo mellow      1  genre        4
# 19           tamaulipas rap      1  genre        4
# 20             sad sierreno      1  genre        4
# 21          mexican hip hop      1  genre        4
# 22             canadian pop      1  genre        4
# 23               pov: indie      1  genre        4
# 24    neo-singer-songwriter      1  genre        4
# Información de las canciones del usuario 5 procesada.
#
# Artistas favoritos:
#                         name  count    type  user_id
# 0                     Axwell      2  artist        5
# 1        Swedish House Mafia      2  artist        5
# 2                       Zedd      1  artist        5
# 3              Three 6 Mafia      1  artist        5
# 4             Kill The Noise      1  artist        5
# 5                     Deorro      1  artist        5
# 6              James Fortune      1  artist        5
# 7                 Ivan Gough      1  artist        5
# 8                Sibali Rida      1  artist        5
# 9              Calvin Harris      1  artist        5
# 10                  Coldplay      1  artist        5
# 11  Dimitri Vangelis & Wyman      1  artist        5
# 12              David Guetta      1  artist        5
#
# Géneros favoritos:
#                               name  count   type  user_id
# 0                              edm     10  genre        5
# 1                        pop dance      9  genre        5
# 2        progressive electro house      7  genre        5
# 3                    electro house      6  genre        5
# 4                      dutch house      4  genre        5
# 5                              pop      4  genre        5
# 6                progressive house      3  genre        5
# 7                       complextro      2  genre        5
# 8                        dance pop      2  genre        5
# 9                       gospel r&b      1  genre        5
# 10  melbourne bounce international      1  genre        5
# 11                          gospel      1  genre        5
# 12                        uk dance      1  genre        5
# 13                   Not Available      1  genre        5
# 14                           house      1  genre        5
# 15                       filthstep      1  genre        5
# 16                  permanent wave      1  genre        5
# 17                melbourne bounce      1  genre        5
# 18               tennessee hip hop      1  genre        5
# 19                    fidget house      1  genre        5
# 20                         brostep      1  genre        5
# 21                            trap      1  genre        5
# 22                southern hip hop      1  genre        5
# 23                 memphis hip hop      1  genre        5
# 24                    gangster rap      1  genre        5
# 25                 dirty south rap      1  genre        5
# 26                           crunk      1  genre        5
# 27                   german techno      1  genre        5
# 28                        big room      1  genre        5
# Información de las canciones del usuario 6 procesada.
#
# Artistas favoritos:
#                    name  count    type  user_id
# 0            The Weeknd      1  artist        6
# 1         Todd Rundgren      1  artist        6
# 2   My Chemical Romance      1  artist        6
# 3       Coconut Records      1  artist        6
# 4             Glasvegas      1  artist        6
# 5          Stick Figure      1  artist        6
# 6            Elton John      1  artist        6
# 7                Hozier      1  artist        6
# 8                Amason      1  artist        6
# 9           Vånna Inget      1  artist        6
# 10           Lil_rebaah      1  artist        6
# 11        Colin Trudell      1  artist        6
# 12        Makthaverskan      1  artist        6
# 13           Mike Mogis      1  artist        6
# 14              AzChike      1  artist        6
#
# Géneros favoritos:
#                          name  count   type  user_id
# 0               Not Available      3  genre        6
# 1                        rock      2  genre        6
# 2                  pov: indie      2  genre        6
# 3                 mellow gold      2  genre        6
# 4                 modern rock      2  genre        6
# 5     irish singer-songwriter      1  genre        6
# 6               reggae fusion      1  genre        6
# 7                 reggae rock      1  genre        6
# 8                   glam rock      1  genre        6
# 9                  piano rock      1  genre        6
# 10  canadian contemporary r&b      1  genre        6
# 11             scottish indie      1  genre        6
# 12           swedish pop punk      1  genre        6
# 13               swedish punk      1  genre        6
# 14                       meme      1  genre        6
# 15           gothenburg indie      1  genre        6
# 16         swedish indie rock      1  genre        6
# 17          swedish post-punk      1  genre        6
# 18              scottish rock      1  genre        6
# 19                 indie rock      1  genre        6
# 20                   la indie      1  genre        6
# 21               indietronica      1  genre        6
# 22               canadian pop      1  genre        6
# 23                   pop punk      1  genre        6
# 24                        emo      1  genre        6
# 25                       zolo      1  genre        6
# 26                  soft rock      1  genre        6
# 27          singer-songwriter      1  genre        6
# 28                  power pop      1  genre        6
# 29                philly soul      1  genre        6
# 30                  folk rock      1  genre        6
# 31               country rock      1  genre        6
# 32                   art rock      1  genre        6
# 33                        pop      1  genre        6
# 34                   cali rap      1  genre        6
# Información de las canciones del usuario 7 procesada.
#
# Artistas favoritos:
#              name  count    type  user_id
# 0       DJ Gollum      1  artist        7
# 1   Bounce Patrol      1  artist        7
# 2         YoungBo      1  artist        7
# 3      Junkie Kid      1  artist        7
# 4      Kris Kross      1  artist        7
# 5            ITZY      1  artist        7
# 6       Kim Leoni      1  artist        7
# 7    William Bell      1  artist        7
# 8         DJ Ross      1  artist        7
# 9       Marc Cohn      1  artist        7
# 10        DJ Roxx      1  artist        7
# 11  Darren Styles      1  artist        7
#
# Géneros favoritos:
#                            name  count   type  user_id
# 0                      hands up      3  genre        7
# 1                 Not Available      2  genre        7
# 2                  german dance      1  genre        7
# 3    old school atlanta hip hop      1  genre        7
# 4                happy hardcore      1  genre        7
# 5                   mellow gold      1  genre        7
# 6                   italo dance      1  genre        7
# 7                 southern soul      1  genre        7
# 8                  memphis soul      1  genre        7
# 9              k-pop girl group      1  genre        7
# 10                        k-pop      1  genre        7
# 11                   miami bass      1  genre        7
# 12                      hip pop      1  genre        7
# 13                      hip hop      1  genre        7
# 14             hardcore hip hop      1  genre        7
# 15                 gangster rap      1  genre        7
# 16                      nursery      1  genre        7
# 17             children's music      1  genre        7
# 18  australian children's music      1  genre        7
# 19              hardcore techno      1  genre        7
# Información de las canciones del usuario 8 procesada.
#
# Artistas favoritos:
#                 name  count    type  user_id
# 0              Leiva      3  artist        8
# 1   Enrique Iglesias      2  artist        8
# 2      One Direction      2  artist        8
# 3       Benson Boone      1  artist        8
# 4             Maluma      1  artist        8
# 5        Demi Lovato      1  artist        8
# 6               Emma      1  artist        8
# 7          Dj Ghosty      1  artist        8
# 8      Los Cantantes      1  artist        8
# 9          Pearl Jam      1  artist        8
# 10            Gojira      1  artist        8
#
# Géneros favoritos:
#                         name  count   type  user_id
# 0                  cantautor      3  genre        8
# 1            latin arena pop      3  genre        8
# 2                  latin pop      3  genre        8
# 3               spanish rock      3  genre        8
# 4                spanish pop      3  genre        8
# 5          spanish indie pop      3  genre        8
# 6                        pop      3  genre        8
# 7              post-teen pop      3  genre        8
# 8                talent show      2  genre        8
# 9                   boy band      2  genre        8
# 10                 dance pop      2  genre        8
# 11               mexican pop      2  genre        8
# 12         alternative metal      2  genre        8
# 13            permanent wave      1  genre        8
# 14          alternative rock      1  genre        8
# 15                      rock      1  genre        8
# 16        french death metal      1  genre        8
# 17              french metal      1  genre        8
# 18              groove metal      1  genre        8
# 19                 hard rock      1  genre        8
# 20                     metal      1  genre        8
# 21                    grunge      1  genre        8
# 22              classic rock      1  genre        8
# 23                  nu metal      1  genre        8
# 24                     gogeo      1  genre        8
# 25                  tropical      1  genre        8
# 26                  guaracha      1  genre        8
# 27                   circuit      1  genre        8
# 28               italian pop      1  genre        8
# 29         italian adult pop      1  genre        8
# 30             urbano latino      1  genre        8
# 31               trap latino      1  genre        8
# 32      reggaeton colombiano      1  genre        8
# 33                 reggaeton      1  genre        8
# 34     singer-songwriter pop      1  genre        8
# 35  progressive groove metal      1  genre        8
# Información de las canciones del usuario 9 procesada.
#
# Artistas favoritos:
#                  name  count    type  user_id
# 0   Justin Timberlake      4  artist        9
# 1         OneRepublic      2  artist        9
# 2      Ellie Goulding      1  artist        9
# 3           DJ Khaled      1  artist        9
# 4                MGMT      1  artist        9
# 5            Kid Cudi      1  artist        9
# 6              MAJOR.      1  artist        9
# 7     Top Hip Hop DJs      1  artist        9
# 8         Major Lazer      1  artist        9
# 9            Nu Breed      1  artist        9
# 10          Shinedown      1  artist        9
#
# Géneros favoritos:
#                  name  count   type  user_id
# 0                 pop      8  genre        9
# 1           dance pop      5  genre        9
# 2        indietronica      2  genre        9
# 3             hip hop      2  genre        9
# 4             pop rap      2  genre        9
# 5                 rap      2  genre        9
# 6          piano rock      2  genre        9
# 7       Not Available      1  genre        9
# 8            nu metal      1  genre        9
# 9   alternative metal      1  genre        9
# 10            redneck      1  genre        9
# 11          pop dance      1  genre        9
# 12         moombahton      1  genre        9
# 13      electro house      1  genre        9
# 14                edm      1  genre        9
# 15       ohio hip hop      1  genre        9
# 16           pop soul      1  genre        9
# 17       metropopolis      1  genre        9
# 18               rock      1  genre        9
# 19        modern rock      1  genre        9
# 20         indie rock      1  genre        9
# 21   alternative rock      1  genre        9
# 22      miami hip hop      1  genre        9
# 23             uk pop      1  genre        9
# 24        post-grunge      1  genre        9
# Información de las canciones del usuario 10 procesada.
#
# Artistas favoritos:
#                      name  count    type  user_id
# 0                 Phoenix      1  artist       10
# 1             St. Vincent      1  artist       10
# 2    Dion's House Kitchen      1  artist       10
# 3     My Chemical Romance      1  artist       10
# 4   The Mamas & The Papas      1  artist       10
# 5                    Zedd      1  artist       10
# 6               Jake Bugg      1  artist       10
# 7             Jakeneutron      1  artist       10
# 8           Isabel LaRosa      1  artist       10
# 9               Ladyhawke      1  artist       10
# 10               Cavetown      1  artist       10
# 11               Bon Iver      1  artist       10
# 12             Pink Floyd      1  artist       10
# 13          Benny Goodman      1  artist       10
# 14                 Hozier      1  artist       10
#
# Géneros favoritos:
#                          name  count   type  user_id
# 0                 modern rock      4  genre       10
# 1                        rock      3  genre       10
# 2                neo-synthpop      3  genre       10
# 3                  pov: indie      3  genre       10
# 4                metropopolis      2  genre       10
# 5                  indie rock      2  genre       10
#           name  count   type  user_id
# 0   girl group      2  genre       19
# 1          pop      2  genre       19
# 2  talent show      2  genre       19
# Información de las canciones del usuario 20 procesada.
#
# Artistas favoritos:
#                  name  count    type  user_id
# 0            Bastille      2  artist       20
# 1            Coldplay      1  artist       20
# 2           Tom Odell      1  artist       20
# 3         James Blunt      1  artist       20
# 4          Ed Sheeran      1  artist       20
# 5      Arctic Monkeys      1  artist       20
# 6             Journey      1  artist       20
# 7         Duke Dumont      1  artist       20
# 8         OneRepublic      1  artist       20
# 9                 ian      1  artist       20
# 10             Mitski      1  artist       20
# 11          Vance Joy      1  artist       20
# 12  A Great Big World      1  artist       20
# 13     Miki Matsubara      1  artist       20
#
# Géneros favoritos:
#                      name  count   type  user_id
# 0                     pop      5  genre       20
# 1             modern rock      4  genre       20
# 2          permanent wave      2  genre       20
# 3              neo mellow      2  genre       20
# 4            metropopolis      2  genre       20
# 5              piano rock      2  genre       20
# 6                    rock      2  genre       20
# 7           Not Available      1  genre       20
# 8       progressive house      1  genre       20
# 9                uk dance      1  genre       20
# 10             pov: indie      1  genre       20
# 11         brooklyn indie      1  genre       20
# 12                  house      1  genre       20
# 13               folk-pop      1  genre       20
# 14               pop rock      1  genre       20
# 15              viral pop      1  genre       20
# 16              pop dance      1  genre       20
# 17            mellow gold      1  genre       20
# 18                    edm      1  genre       20
# 19              soft rock      1  genre       20
# 20              hard rock      1  genre       20
# 21           classic rock      1  genre       20
# 22             album rock      1  genre       20
# 23        sheffield indie      1  genre       20
# 24            garage rock      1  genre       20
# 25                 uk pop      1  genre       20
# 26  singer-songwriter pop      1  genre       20
# 27              chill pop      1  genre       20
# 28       classic city pop      1  genre       20
# Información de las canciones del usuario 21 procesada.
#
# Artistas favoritos:
#                             name  count    type  user_id
# 0                          JAY-Z      4  artist       21
# 1                          USHER      1  artist       21
# 2                        J. Cole      1  artist       21
# 3                    Chris Brown      1  artist       21
# 4                     Snoop Dogg      1  artist       21
# 5                    Cheryl Lynn      1  artist       21
# 6                   Walker Hayes      1  artist       21
# 7                     Kanye West      1  artist       21
# 8            Westside Connection      1  artist       21
# 9   Lil Jon & The East Side Boyz      1  artist       21
# 10                      Ice Cube      1  artist       21
# 11                      The Game      1  artist       21
# 12                         B.o.B      1  artist       21
# 13                         Drake      1  artist       21
#
# Géneros favoritos:
#                           name  count   type  user_id
# 0                          rap     13  genre       21
# 1                      hip hop     10  genre       21
# 2                 gangster rap      8  genre       21
# 3                      pop rap      8  genre       21
# 4           east coast hip hop      4  genre       21
# 5             southern hip hop      3  genre       21
# 6               west coast rap      3  genre       21
# 7                       g funk      3  genre       21
# 8                  atl hip hop      3  genre       21
# 9            conscious hip hop      2  genre       21
# 10          urban contemporary      2  genre       21
# 11                         r&b      2  genre       21
# 12                   dance pop      2  genre       21
# 13             detroit hip hop      1  genre       21
# 14                     country      1  genre       21
# 15                        trap      1  genre       21
# 16            canadian hip hop      1  genre       21
# 17  old school atlanta hip hop      1  genre       21
# 18             dirty south rap      1  genre       21
# 19                       crunk      1  genre       21
# 20                atlanta bass      1  genre       21
# 21                 chicago rap      1  genre       21
# 22         modern country rock      1  genre       21
# 23                country road      1  genre       21
# 24                        funk      1  genre       21
# 25        contemporary country      1  genre       21
# 26                        soul      1  genre       21
# 27                 quiet storm      1  genre       21
# 28                  post-disco      1  genre       21
# 29           minneapolis sound      1  genre       21
# 30            contemporary r&b      1  genre       21
# 31                       disco      1  genre       21
# 32                classic soul      1  genre       21
# 33      north carolina hip hop      1  genre       21
# 34      south carolina hip hop      1  genre       21
# 35                         pop      1  genre       21
# 36                canadian pop      1  genre       21
# Información de las canciones del usuario 22 procesada.
#
# Artistas favoritos:
#                  name  count    type  user_id
# 0              Avicii      3  artist       22
# 1               Adele      1  artist       22
# 2          The Wrecks      1  artist       22
# 3       Paperboy Fabe      1  artist       22
# 4            Level 42      1  artist       22
# 5       In Full Color      1  artist       22
# 6            Crush 40      1  artist       22
# 7    Wolfgang Gartner      1  artist       22
# 8   Catch Your Breath      1  artist       22
# 9               Keane      1  artist       22
# 10              Gotye      1  artist       22
# 11             Savant      1  artist       22
# 12               Zedd      1  artist       22
#
# Géneros favoritos:
#                          name  count   type  user_id
# 0                         pop      5  genre       22
# 1                         edm      5  genre       22
# 2                   pop dance      4  genre       22
# 3                   dance pop      3  genre       22
# 4                  complextro      3  genre       22
# 5                vocal trance      1  genre       22
# 6                   filthstep      1  genre       22
# 7              australian pop      1  genre       22
# 8                    pop rock      1  genre       22
# 9                  piano rock      1  genre       22
# 10                 neo mellow      1  genre       22
# 11         american metalcore      1  genre       22
# 12  progressive electro house      1  genre       22
# 13                      house      1  genre       22
# 14              electro house      1  genre       22
# 15                    j-metal      1  genre       22
# 16               sophisti-pop      1  genre       22
# 17                   synthpop      1  genre       22
# 18                 post-disco      1  genre       22
# 19               new wave pop      1  genre       22
# 20               new romantic      1  genre       22
# 21                 dance rock      1  genre       22
# 22                  brit funk      1  genre       22
# 23              Not Available      1  genre       22
# 24                 pov: indie      1  genre       22
# 25                   la indie      1  genre       22
# 26                     uk pop      1  genre       22
# 27                   pop soul      1  genre       22
# 28               british soul      1  genre       22
# 29              german techno      1  genre       22
# Información de las canciones del usuario 23 procesada.
#
# Artistas favoritos:
#                              name  count    type  user_id
# 0                    Lana Del Rey      2  artist       23
# 1                          Hozier      2  artist       23
# ...
# 10                                     TLC      1  artist       27
# 11                                  nimino      1  artist       27
# 12                         Aretha Franklin      1  artist       27
# 13                           Basement Jaxx      1  artist       27
#
# Géneros favoritos:
#                      name  count   type  user_id
# 0            classic rock      3  genre       27
# 1              album rock      3  genre       27
# 2                     r&b      3  genre       27
# 3                    rock      3  genre       27
# 4                     pop      3  genre       27
# 5            classic soul      2  genre       27
# 6        british invasion      2  genre       27
# 7                    soul      2  genre       27
# 8            memphis soul      2  genre       27
# 9                 hip pop      2  genre       27
# 10                    rap      2  genre       27
# 11     urban contemporary      2  genre       27
# 12             vocal jazz      1  genre       27
# 13          southern soul      1  genre       27
# 14             jazz blues      1  genre       27
# 15      alternative dance      1  genre       27
# 16          melodic house      1  genre       27
# 29        canadian pop punk      1  genre       30
# 30               dance rock      1  genre       30
# 31                halloween      1  genre       30
# 32              piano cover      1  genre       30
# Información de las canciones del usuario 31 procesada.
#
# Artistas favoritos:
#                 name  count    type  user_id
# 0      Calvin Harris      2  artist       31
# 1             Avicii      2  artist       31
# 2   TOOMANYLEFTHANDS      1  artist       31
# 3            Stromae      1  artist       31
# 4           Hardwell      1  artist       31
# 5          Disciples      1  artist       31
# 6               XANU      1  artist       31
# 7        Blasterjaxx      1  artist       31
# 8       Gareth Emery      1  artist       31
# 9         Rudimental      1  artist       31
# 10          deadmau5      1  artist       31
# 11       Leona Lewis      1  artist       31
# 12    Ellie Goulding      1  artist       31
# 13         Dada Life      1  artist       31
# 14          Rodney O      1  artist       31
# 15             Malpa      1  artist       31
# 16         Judy Kuhn      1  artist       31
#
# Géneros favoritos:
#                          name  count   type  user_id
# 0                   pop dance     11  genre       31
# 1                         edm      9  genre       31
# 2           progressive house      6  genre       31
# 3                         pop      6  genre       31
# 4               electro house      6  genre       31
# 5                   dance pop      5  genre       31
# 6                    uk dance      4  genre       31
# 7   progressive electro house      4  genre       31
# 8                 dutch house      3  genre       31
# 9                       house      3  genre       31
# 10                   big room      3  genre       31
# 11              Not Available      2  genre       31
# 12        canadian electronic      1  genre       31
# 13                talent show      1  genre       31
# 14               indietronica      1  genre       31
# 15               metropopolis      1  genre       31
# 16               british soul      1  genre       31
# 17                     uk pop      1  genre       31
# 18                    electro      1  genre       31
# 19                 complextro      1  genre       31
# 20                movie tunes      1  genre       31
# 21                   uk funky      1  genre       31
# 22                 slap house      1  genre       31
# 23                    g-house      1  genre       31
# 24                belgian pop      1  genre       31
# 25                  scandipop      1  genre       31
# 26          danish electronic      1  genre       31
# 27                     trance      1  genre       31
# 28                 miami bass      1  genre       31
# Información de las canciones del usuario 32 procesada.
#
# Artistas favoritos:
#                      name  count    type  user_id
# 0            Marc Anthony      2  artist       32
# 1                  Juanes      2  artist       32
# 2              Celia Cruz      2  artist       32
# 3          Roberto Carlos      1  artist       32
# 4              Olga Tañón      1  artist       32
# 5            David Bisbal      1  artist       32
# 6            Carlos Vives      1  artist       32
# 7     Banda Los Recoditos      1  artist       32
# 8            Willie Colón      1  artist       32
# 9                     DLG      1  artist       32
# 10         Ritchie Valens      1  artist       32
# 11              Azul Azul      1  artist       32
# 12  Juan Luis Guerra 4.40      1  artist       32
# 13          Sergio Vargas      1  artist       32
# 14                  Kaoma      1  artist       32
# 15    Los Enanitos Verdes      1  artist       32
#
# Géneros favoritos:
#                          name  count   type  user_id
# 0                   latin pop      9  genre       32
# 1                       salsa      7  genre       32
# 2                    tropical      7  genre       32
# 3               colombian pop      3  genre       32
# 4                 mexican pop      3  genre       32
# 5             rock en espanol      3  genre       32
# 6                modern salsa      2  genre       32
# 7   musica tradicional cubana      2  genre       32
# 8                       mambo      2  genre       32
# 9                 cuban rumba      2  genre       32
# 10                cha-cha-cha      2  genre       32
# 11          latin alternative      1  genre       32
# 12             argentine rock      1  genre       32
# 13                 latin rock      1  genre       32
# 14                       zouk      1  genre       32
# 15                   merengue      1  genre       32
# 16                    bachata      1  genre       32
# 17               jovem guarda      1  genre       32
# 18              rock-and-roll      1  genre       32
# 19              pop boliviano      1  genre       32
# 20                 rockabilly      1  genre       32
# 21                        mpb      1  genre       32
# 22                    norteno      1  genre       32
# 23            musica mexicana      1  genre       32
# 24           banda sinaloense      1  genre       32
# 25                      banda      1  genre       32
# 26                  vallenato      1  genre       32
# 27           spanish pop rock      1  genre       32
# 28            latin arena pop      1  genre       32
# 29           puerto rican pop      1  genre       32
# 30              ska argentino      1  genre       32
# Artistas y géneros favoritos de todos los usuarios guardados en all_favorites.csv.

# %% [markdown]
# Generar csv de todos los  usuarios

# %%
def get_user_song_info(user_id, df):
    # Filtrar las canciones por el ID del usuario
    user_songs = df[df['user_id'] == user_id]['song_name']

    # Obtener información de todas las canciones del usuario
    song_infos = [get_song_info(song) for song in user_songs]

    # Filtrar los valores None
    song_infos = [info for info in song_infos if info is not None]

    # Convertir a DataFrame para análisis
    song_info_df = pd.DataFrame(song_infos)
    song_info_df['user_id'] = user_id  # Agregar columna de ID de usuario

    return song_info_df

# %%
# Obtener la lista de usuarios únicos
user_ids = df['user_id'].unique()

df = pd.read_csv('/content/spotify_dataset.csv')
df.columns = df.columns.str.strip()
# DataFrame para consolidar toda la información
all_song_info = pd.DataFrame()

# Procesar información para todos los usuarios
for user_id in user_ids:
    song_info_df = get_user_song_info(user_id, df)
    print(f"Información de las canciones del usuario {user_id} procesada.")
    all_song_info = pd.concat([all_song_info, song_info_df], ignore_index=True)

# Guardar toda la información en un solo archivo CSV
all_song_info.to_csv('/content/users_info.csv', index=False)

print("Información de todas las canciones guardada en users_info.csv.")
# Out:
# Información de las canciones del usuario 1 procesada.
# Información de las canciones del usuario 2 procesada.
# Información de las canciones del usuario 3 procesada.
# Información de las canciones del usuario 4 procesada.
# Información de las canciones del usuario 5 procesada.
# Información de las canciones del usuario 6 procesada.
# Información de las canciones del usuario 7 procesada.
# Información de las canciones del usuario 8 procesada.
# Información de las canciones del usuario 9 procesada.
# Información de las canciones del usuario 10 procesada.
# Información de las canciones del usuario 11 procesada.
# Información de las canciones del usuario 12 procesada.
# Información de las canciones del usuario 13 procesada.
# Información de las canciones del usuario 14 procesada.
# Información de las canciones del usuario 15 procesada.
# Información de las canciones del usuario 16 procesada.
# Información de las canciones del usuario 17 procesada.
# Información de las canciones del usuario 18 procesada.
# Información de las canciones del usuario 19 procesada.
# Información de las canciones del usuario 20 procesada.
# Información de todas las canciones guardada en users_info.csv.

# %% [markdown]
# # **Visualización de Resultados: Presenten los resultados de forma atractiva, utilizando gráficos, mapas y otras herramientas de visualización.**

# %%
import pandas as pd

# Cargar el dataset
df = pd.read_csv('all_favorites.csv')

# Filtrar los datos por tipo (artista o género)
artists_df = df[df['type'] == 'artist']
genres_df = df[df['type'] == 'genre']

# Obtener los top 5 artistas y géneros por usuario
top_artists = artists_df.groupby(['user_id', 'name']).agg({'count': 'sum'}).reset_index()
top_genres = genres_df.groupby(['user_id', 'name']).agg({'count': 'sum'}).reset_index()

top_artists = top_artists.sort_values(['user_id', 'count'], ascending=[True, False]).groupby('user_id').head(5)
top_genres = top_genres.sort_values(['user_id', 'count'], ascending=[True, False]).groupby('user_id').head(5)

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# Inicializar la aplicación Dash
app = dash.Dash(__name__)

# Layout de la aplicación
app.layout = html.Div([
    html.H1("Dashboard de Preferencias Musicales de Usuarios"),

    html.Label("Selecciona un Usuario:"),
    dcc.Dropdown(
        id='user-dropdown',
        options=[{'label': f'Usuario {user_id}', 'value': user_id} for user_id in df['user_id'].unique()],
        value=df['user_id'].unique()[0]  # Seleccionar el primer usuario por defecto
    ),

    html.Div([
        dcc.Graph(id='artist-pie-chart'),
        dcc.Graph(id='genre-pie-chart')
    ])
])

# Callback para actualizar los gráficos
@app.callback(
    [Output('artist-pie-chart', 'figure'), Output('genre-pie-chart', 'figure')],
    [Input('user-dropdown', 'value')]
)
def update_charts(selected_user):
    # Filtrar los datos por el usuario seleccionado
    user_artists = top_artists[top_artists['user_id'] == selected_user]
    user_genres = top_genres[top_genres['user_id'] == selected_user]

    # Crear el gráfico de torta para los artistas
    artist_pie_chart = px.pie(user_artists, names='name', values='count', title=f'Top 5 Artistas del Usuario {selected_user}')

    # Crear el gráfico de torta para los géneros
    genre_pie_chart = px.pie(user_genres, names='name', values='count', title=f'Top 5 Géneros del Usuario {selected_user}')

    return artist_pie_chart, genre_pie_chart

# Ejecutar la aplicación
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# # **Recomendaciones Musicales: Desarrollen un sistema de recomendación de música personalizado para cada usuario en función de sus preferencias**

# %%
import pandas as pd
import difflib

# Lista de géneros soportados por Spotify
spotify_genres = [
    'acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient', 'anime',
    'black-metal', 'bluegrass', 'blues', 'bossanova', 'brazil', 'breakbeat',
    'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical',
    'club', 'comedy', 'country', 'dance', 'dancehall', 'death-metal',
    'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub',
    'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french',
    'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
    'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
    'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm',
    'indian', 'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol',
    'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay',
    'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies',
    'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party',
    'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-pop',
    'progressive-house', 'psych-rock', 'punk', 'punk-rock', 'r-n-b', 'rainy-day',
    'reggae', 'reggaeton', 'road-trip', 'rock', 'rock-n-roll', 'rockabilly',
    'romance', 'sad', 'salsa', 'samba', 'sertanejo', 'show-tunes',
    'singer-songwriter', 'ska', 'sleep', 'songwriter', 'soul', 'soundtracks',
    'spanish', 'study', 'summer', 'swedish', 'synth-pop', 'tango', 'techno',
    'trance', 'trip-hop', 'turkish', 'work-out', 'world-music'
]

# Función para encontrar el género más cercano permitido por Spotify
def find_closest_genre(genre, spotify_genres):
    closest_matches = difflib.get_close_matches(genre, spotify_genres, n=1, cutoff=0.6)
    return closest_matches[0] if closest_matches else None

# Función para convertir los géneros de usuario a géneros de Spotify y guardarlos
def convert_and_save_genres(df):
    user_genre_counts = {}

    for index, row in df.iterrows():
        if row['type'] == 'genre':
            genre = row['name'].strip()
            closest_genre = find_closest_genre(genre, spotify_genres)
            if closest_genre:
                user_id = row['user_id']
                count = row['count']

                # Actualizar el conteo del género por user_id
                if user_id in user_genre_counts:
                    if closest_genre in user_genre_counts[user_id]:
                        user_genre_counts[user_id][closest_genre] += count
                    else:
                        user_genre_counts[user_id][closest_genre] = count
                else:
                    user_genre_counts[user_id] = {closest_genre: count}

    # Crear DataFrame con los resultados
    result_data = []
    for user_id, genre_counts in user_genre_counts.items():
        sorted_genres = sorted(genre_counts.items(), key=lambda x: x[1], reverse=True)[:5]  # Obtener top 5 géneros
        for genre, count in sorted_genres:
            result_data.append({
                'genres': genre,
                'user_id': user_id
            })

    result_df = pd.DataFrame(result_data)

    # Guardar los resultados en un nuevo CSV
    result_df.to_csv('top_5_genres_per_user.csv', index=False)
    print("Top 5 genres per user saved to top_5_genres_per_user.csv")

# Cargar el dataset original
df = pd.read_csv('/content/all_favorites.csv')

# Filtrar solo las filas de tipo 'genre'
genres_df = df[df['type'] == 'genre']

# Convertir y guardar los géneros con información extendida
convert_and_save_genres(genres_df)
# Out:
# Top 5 genres per user saved to top_5_genres_per_user.csv

# %%
# Función para obtener recomendaciones de canciones
def get_recommendations(seed_genres=[], seed_artists=[], seed_tracks=[], limit=10):
    recommendations = sp.recommendations(seed_genres=seed_genres, seed_artists=seed_artists, seed_tracks=seed_tracks, limit=limit)
    return recommendations['tracks']

# Función para obtener recomendaciones de canciones para cada usuario y guardar en un CSV
def recommend_songs_for_users(input_csv, output_csv):
    # Cargar el CSV de entrada
    df = pd.read_csv(input_csv)

    # Diccionario para almacenar recomendaciones por usuario
    recommendations_data = []

    # Obtener recomendaciones para cada usuario
    for user_id in df['user_id'].unique():
        # Obtener los géneros del usuario
        user_genres = df[df['user_id'] == user_id]['genres'].tolist()

        # Obtener recomendaciones basadas en los géneros del usuario
        recommendations = get_recommendations(seed_genres=user_genres, limit=10)

        # Guardar las recomendaciones en el diccionario e imprimirlas
        print(f"\nRecomendaciones para el usuario {user_id}:")
        for idx, track in enumerate(recommendations):
            track_name = track['name']
            artist_names = ', '.join([artist['name'] for artist in track['artists']])
            recommendations_data.append({
                'user_id': user_id,
                'track_name': track_name,
                'artist_name': artist_names
            })
            print(f"{idx + 1}. {track_name} - {artist_names}")

    # Crear DataFrame con las recomendaciones
    recommendations_df = pd.DataFrame(recommendations_data)

    # Guardar las recomendaciones en un nuevo CSV
    recommendations_df.to_csv(output_csv, index=False)
    print(f"\nRecomendaciones guardadas en {output_csv}")

# Ejecutar la función con el CSV cargado
input_csv_path = '/content/top_5_genres_per_user.csv'
output_csv_path = 'recommendations_per_user.csv'
recommend_songs_for_users(input_csv_path, output_csv_path)
# Out:
# Recomendaciones para el usuario 1:
# 1. If The Creek Don’t Rise - Dylan LeBlanc
# 2. Kiss Me - Ed Sheeran
# 3. Sadeness - Enigma
# 4. The Old Laughing Lady - The Orange Peels
# 5. Theme and Variations - Ruth Crawford Seeger, Jenny Lin
# 6. Angel - Sarah McLachlan
# 7. One More Light - Linkin Park
# 8. Madre De La Tierra - David Lanz, The IFS Philharmonic Orchestra of Munich
# 9. Boy Or A Girl - Imperial Drag
# 10. Slice of Life - The Bigger Lovers
#
# Recomendaciones para el usuario 2:
# 1. Tremor Christ - Remastered - Pearl Jam
# 2. How We Do - Original Mix - Hardwell, Showtek
# 3. Chasing Cars - Snow Patrol
# 4. Last Resort - Papa Roach
# 5. Summer - Calvin Harris
# 6. Strobe - deadmau5
# 7. Technologic - Daft Punk
# 8. Frogs - Alice In Chains
# 9. School - Remastered - Nirvana
# 10. This Is War - Thirty Seconds To Mars
#
# Recomendaciones para el usuario 3:
# 1. Promises, Promises - Incubus
# 2. I Will Get Lost, You Go Your Way - English Version - G.NA, Yong Jun Hyung
# 3. Dollhouse - Melanie Martinez
# 4. 7 Years - Lukas Graham
# 5. 爛泥 - Andy Hui
# 6. Samson - Regina Spektor
# 7. Hey Brother - Avicii
# 8. Angel - Sarah McLachlan
# 9. 勁歌金曲3 - Party King - Leo Ku
# 10. Paranoid - Black Sabbath
#
# Recomendaciones para el usuario 4:
# 1. Let Me Live (feat. Anne-Marie & Mr Eazi) - Rudimental, Major Lazer, Anne-Marie, Mr Eazi
# 2. Testify - Rage Against The Machine
# 3. Who Do You Love? - YG, Drake
# 4. My Love for Evermore - The Hillbilly Moon Explosion, Mark 'Sparky' Philips
# 5. Nutshell - Alice In Chains
# 6. Visa vid vindens ängar - Håkan Hellström
# 7. Let's Make Out - Dream Wife
# 8. Ska vi älska, så ska vi älska till Buddy Holly - Gyllene Tider
# 9. Stockholm i mitt hjärta - Petter
# 10. Love, Hate, Love - Alice In Chains
#
# Recomendaciones para el usuario 5:
# 1. Devotion - Radio Edit - Quintino
# 2. Giving It All - Bondax
# 3. Sexual Healing - Kygo Radio Edit - Marvin Gaye, Kygo
# 4. So Young So High - Dada Life
# 5. We Plants Are Happy Plants - We Plants Are Happy Plants
# 6. Be Together (feat. Wild Belle) - Major Lazer, Wild Belle
# 7. Goodbye (feat. Lyse) - Radio Edit - Feder, Lyse
# 8. Shot Me Down (feat. Skylar Grey) - Radio Edit - David Guetta, Skylar Grey
# 9. STREET - NGHTMRE
# 10. Lionheart - Original Mix - AFROJACK
#
# Recomendaciones para el usuario 6:
# 1. Loco - Jowell & Randy
# 2. Aquarium - Nosaj Thing
# 3. Misery Business - Paramore
# 4. Fanfanfan - Thåström
# 5. 29 #Strafford APTS - Bon Iver
# 6. Love It If We Made It - The 1975
# 3. O Mio Babbino Caro - Maria Callas
# 4. Rimsky-Korsakov: The Tsar's Bride, Act I: Lyubasha's Song. "Snaryazhay skoryy matushka rodimaya" - Nikolai Rimsky-Korsakov, Galina Vishnevskaya, Mstislav Rostropovich, London Philharmonic Orchestra
# 5. Paper Cuts - Remastered - Nirvana
# 6. Centuries - Fall Out Boy
# 7. All The Small Things - blink-182
# 8. Rigoletto / Act III: "La donna è mobile" (Rigoletto) - Giuseppe Verdi, Plácido Domingo, Wiener Philharmoniker, Carlo Maria Giulini
# 9. Zombie - Bad Wolves
# 10. River - Bishop Briggs
#
# Recomendaciones para el usuario 30:
# 1. Basket Case - Green Day
# 2. This Is War - Thirty Seconds To Mars
# 3. Praying - Kesha
# 4. All The Stars (with SZA) - Kendrick Lamar, SZA
# 5. Harbour - Safeguard
# 6. I Feel It Coming - The Weeknd, Daft Punk
# 7. Sleepyhead - Passion Pit
# 8. Alternative Ulster - Stiff Little Fingers
# 9. It's Been Awhile - Staind
# 10. Domino - Jessie J
#
# Recomendaciones para el usuario 31:
# 1. Odessa - Caribou
# 2. STREET - NGHTMRE
# 3. Feel So Close - Nero Remix - Calvin Harris
# 4. Au Seve - Julio Bashmore
# 5. Fatality - Quintino Edit - Pep & Rash, Quintino
# 6. Welcome To St. Tropez (DJ Antoine Vs. Mad Mark Radio Edit) - DJ Antoine, Timati, Kalenna
# 7. The End (Original Mix) - Tommy Trash
# 8. Wizard - Radio Edit - Martin Garrix, Jay Hardway
# 9. Booty Swing - Parov Stelar
# 10. I.D.G.A.F.O.S. - Dillon Francis
#
# Recomendaciones para el usuario 32:
# 1. Devuelveme A Mi Chica - Hombres G
# 2. Creo en Ti - Reik
# 3. Me Llamaré Tuyo - Víctor Manuelle
# 4. Brujeria - El Gran Combo De Puerto Rico
# 5. Corazón En La Maleta - Luis Fonsi
# 6. Madness - Muse
# 7. Menina Moça - João Bosco
# 8. Interstate Love Song - Stone Temple Pilots
# 9. Electric Feel - MGMT
# 10. 愛上一個不回家的人 - Sandy Lam, Wong Kei Wah
#
# Recomendaciones guardadas en recommendations_per_user.csv

# %% [markdown]
# Evaluacion de la funcion recomendacion , la funcion que utilizada un csv vs la funcion que se ingresa manualmente los generos

# %%
# Función para obtener recomendaciones de canciones
def get_recommendations(seed_genres=[], seed_artists=[], seed_tracks=[], limit=10):
    recommendations = sp.recommendations(seed_genres=seed_genres, seed_artists=seed_artists, seed_tracks=seed_tracks, limit=limit)
    return recommendations['tracks']

# Función para obtener los géneros de los artistas de una canción
def get_track_genres(track):
    artist_ids = [artist['id'] for artist in track['artists']]
    genres = set()
    for artist_id in artist_ids:
        artist_info = sp.artist(artist_id)
        genres.update(artist_info['genres'])
    return list(genres)

# Ejemplo de obtener recomendaciones basadas en los géneros de las canciones favoritas
seed_genres = ['rock', 'singer-songwriter', 'new-age', 'power-pop', 'classical']
recommendations = get_recommendations(seed_genres=seed_genres, limit=10)

# Imprimir las recomendaciones obtenidas con géneros
print("Recomendaciones de canciones:")
for idx, track in enumerate(recommendations):
    track_genres = get_track_genres(track)
    track_genres_display = ', '.join(track_genres[:4])  # Mostrar hasta 4 géneros
    print(f"{idx+1}. {track['name']} - {', '.join([artist['name'] for artist in track['artists']])} | Géneros: {track_genres_display}")
# Out:
# Recomendaciones de canciones:
# 1. Opening - Philip Glass, Bruce Brubaker | Géneros: contemporary classical, compositional ambient, classical, classical piano
# 2. Fantasien op. 116: Intermezzo: Adagio - Johannes Brahms, Martin Tchiba | Géneros: classical, late romantic era, german romanticism, german classical piano
# 3. Clarinet Concerto in B-Flat Major (reconstructed R. Meylan): I. Andante sostenuto - Gaetano Donizetti, Raymond Meylan, Béla Kovács, Camerata De Budapest, Laszlo Kovacs | Géneros: opera, italian romanticism, early romantic era, classical
# 4. Rigoletto / Act 3: "La donna è mobile" - Giuseppe Verdi, Luciano Pavarotti, London Symphony Orchestra, Richard Bonynge | Géneros: operatic pop, opera, late romantic era, italian romanticism
# 5. Are You Gonna Be My Girl - Jet | Géneros: pop rock, garage rock, modern rock
# 6. Temptation Eyes - Blake Babies | Géneros: boston rock, alternative pop
# 7. Teenagers - My Chemical Romance | Géneros: rock, pop punk, pov: indie, modern rock
# 8. Madre De La Tierra - David Lanz, The IFS Philharmonic Orchestra of Munich | Géneros: new age piano, new age
# 9. Song #3 - Stone Sour | Géneros: post-grunge, alternative metal, nu metal
# 10. Cello Suite No. 5 in C Minor, BWV 1011: II. Allemande - Johann Sebastian Bach, Yo-Yo Ma | Géneros: baroque, chamber ensemble, classical performance, classical

# %%
# Función para obtener recomendaciones de canciones
def get_recommendations(seed_genres=[], seed_artists=[], seed_tracks=[], limit=10):
    recommendations = sp.recommendations(seed_genres=seed_genres, seed_artists=seed_artists, seed_tracks=seed_tracks, limit=limit)
    return recommendations['tracks']

# Función para obtener los géneros de los artistas de una canción
def get_track_genres(track):
    artist_ids = [artist['id'] for artist in track['artists']]
    genres = set()
    for artist_id in artist_ids:
        artist_info = sp.artist(artist_id)
        genres.update(artist_info['genres'])
    return list(genres)

# Función para obtener recomendaciones de canciones para cada usuario y guardar en un CSV
def recommend_songs_for_users(input_csv, output_csv):
    # Cargar el CSV de entrada
    df = pd.read_csv(input_csv)

    # Diccionario para almacenar recomendaciones por usuario
    recommendations_data = []

    # Obtener recomendaciones para cada usuario
    for user_id in df['user_id'].unique():
        # Obtener los géneros del usuario
        user_genres = df[df['user_id'] == user_id]['genres'].tolist()

        # Obtener recomendaciones basadas en los géneros del usuario
        recommendations = get_recommendations(seed_genres=user_genres, limit=10)

        # Guardar las recomendaciones en el diccionario e imprimirlas
        print(f"\nRecomendaciones para el usuario {user_id}:")
        for idx, track in enumerate(recommendations):
            track_name = track['name']
            artist_names = ', '.join([artist['name'] for artist in track['artists']])
            track_genres = get_track_genres(track)
            track_genres_display = ', '.join(track_genres[:4])  # Mostrar hasta 4 géneros

            recommendations_data.append({
                'user_id': user_id,
                'track_name': track_name,
                'artist_name': artist_names,
                'genres': track_genres_display
            })

            print(f"{idx + 1}. {track_name} - {artist_names} | Géneros: {track_genres_display}")

    # Crear DataFrame con las recomendaciones
    recommendations_df = pd.DataFrame(recommendations_data)

    # Guardar las recomendaciones en un nuevo CSV
    recommendations_df.to_csv(output_csv, index=False)
    print(f"\nRecomendaciones guardadas en {output_csv}")

# Ejecutar la función con el CSV cargado
input_csv_path = '/content/top_5_genres_per_user.csv'
output_csv_path = 'recommendations_per_user.csv'
recommend_songs_for_users(input_csv_path, output_csv_path)
# Out:
# Recomendaciones para el usuario 1:
# 1. Sleeping Lotus - Joep Beving | Géneros: neo-classical, compositional ambient
# 2. The Lonesome Boatman - Dropkick Murphys | Géneros: celtic punk, celtic rock, boston rock, boston punk
# 3. Someday - Yanni | Géneros: new age
# 4. Awaken (feat. Jack Liebeck) - Dario Marianelli, Jack Liebeck, Benjamin Wallfisch | Géneros: violin, deep soundtrack, orchestral soundtrack, soundtrack
# 5. Balloon Man - Robyn Hitchcock & The Egyptians | Géneros: power pop, jangle pop
# 6. Talking In Your Sleep (2023 Remaster) - The Romantics | Géneros: mellow gold, new wave pop, power pop, soft rock
# 7. Fairytale - Enya | Géneros: operatic pop, celtic, gregorian dance
# 8. Over and Over Again - The Used | Géneros: post-grunge, pop emo, screamo, alternative metal
# 9. Yellow Ledbetter - Pearl Jam | Géneros: rock, grunge, alternative rock, alternative metal
# 10. Conquest of Paradise - Vangelis | Géneros: cyberpunk, synthesizer
#
# Recomendaciones para el usuario 2:
# 1. TV Party - Black Flag | Géneros: alternative rock, california hardcore, hardcore punk, punk
# 2. My Little RnR - Danko Jones | Géneros: punk 'n' roll
# 3. Carry On - fun. | Géneros: metropopolis, baroque pop
# 4. Ride - Lana Del Rey | Géneros: pop, art pop
# 5. Where Did You Sleep Last Night - Nirvana | Géneros: grunge, permanent wave, rock
# 6. Blood - Remastered - Pearl Jam | Géneros: rock, grunge, alternative rock, alternative metal
# 7. Zero - Remastered 2012 - The Smashing Pumpkins | Géneros: rock, grunge, alternative rock, spacegrunge
# 8. D.A.N.C.E. - Justice | Géneros: indietronica, dance-punk, new rave, alternative dance
# 9. Kill Your Heroes - AWOLNATION | Géneros: la indie, rock, stomp pop, modern alternative rock
# 10. Angry Chair (2022 Remaster) - Alice In Chains | Géneros: rock, grunge, alternative rock, alternative metal
#
# Recomendaciones para el usuario 3:
# 1. Star - Jay Park | Géneros: k-rap, korean r&b, k-pop
# 2. Criminal - Fiona Apple | Géneros: dark pop, piano rock, chamber pop, art pop
# 3. 狂野之城 - Aaron Kwok, 黃尚偉, John Lin Ming | Géneros: cantopop, c-pop, classic cantopop
# 4. Pray For Me (with Kendrick Lamar) - The Weeknd, Kendrick Lamar | Géneros: hip hop, canadian pop, pop, conscious hip hop
# 5. Alone - Heart | Géneros: mellow gold, rock, new wave pop, glam metal
# 6. Keep It Loose, Keep It Tight - Amos Lee | Géneros: neo mellow, stomp and holler, acoustic pop
# 7. Harvest Moon - Neil Young | Géneros: mellow gold, roots rock, rock, folk rock
# 8. Man On The Silver Mountain - Rainbow | Géneros: rock, metal, glam metal, album rock
# 9. Smoke on the Water (45 Version) - Deep Purple | Géneros: rock, metal, album rock, classic rock
# 10. White Room - Cream | Géneros: rock, blues rock, supergroup, psychedelic rock
#
# Recomendaciones para el usuario 4:
# 1. Sakta vi gå genom stan - Monica Zetterlund | Géneros: classic swedish pop, swedish jazz
# 2. Vasoline - Stone Temple Pilots | Géneros: rock, grunge, alternative rock, post-grunge
# 3. (Kom så ska vi) Leva livet - Gyllene Tider | Géneros: swedish pop, classic swedish pop
# 4. The Zookeeper's Boy - Mew | Géneros: melancholia, danish rock, dream pop, danish alternative rock
# 5. The Wind Cries Mary - Jimi Hendrix | Géneros: rock, alternative rock, psychedelic rock, proto-metal
# 6. Even Flow - Pearl Jam | Géneros: rock, grunge, alternative rock, alternative metal
# 7. Gravity - Papa Roach | Géneros: rap metal, rock, alternative metal, nu metal
# 8. Angry Chair (2022 Remaster) - Alice In Chains | Géneros: rock, grunge, alternative rock, alternative metal
# 9. House On Fire - Rise Against | Géneros: chicago hardcore, post-grunge, pop punk, chicago punk
# 10. Visa vid vindens ängar - Håkan Hellström | Géneros: gothenburg indie, swedish indie rock, classic swedish pop, swedish pop
#
# Recomendaciones para el usuario 5:
# 1. Mantaz - Original Mix - No ID | Géneros:
# 2. Rock Steady - Original Mix - Julian Jordan | Géneros: edm, sky room, electro house, dutch house
# 3. Headlights (feat. Ilsey) - Robin Schulz, Ilsey | Géneros: edm, tropical house, german dance, deep euro house
# 4. Generation 303 (Original Mix) - Nicky Romero | Géneros: edm, big room, electro house, dutch house
# 5. Kameha - Original Mix - Gregori Klosman | Géneros: progressive electro house
# 6. Show Me Love - EDX Remix / Radio Edit - Sam Feldt, Kimberly Anne, EDX | Géneros: edm, tropical house, swiss pop, house
# 7. Turn Down for What - DJ Snake, Lil Jon | Géneros: edm, trap, atl hip hop, southern hip hop
# 8. What's Your Name - Dillon Francis, Calvin Harris | Géneros: edm, slap house, pop, brostep
# 9. Like Home - Radio Edit - Nicky Romero, NERVO | Géneros: edm, big room, house, australian dance
# 10. Wasted - Tiësto, Matthew Koma | Géneros: edm, slap house, pop edm, trance
#
# Recomendaciones para el usuario 6:
# 1. Quarter Past Midnight - Bastille | Géneros: pop, metropopolis, modern rock
# 2. Better Together - Jack Johnson | Géneros: neo mellow
# 3. The Writing's on the Wall - OK Go | Géneros: chicago indie, permanent wave, modern rock
# 4. Angel - Sarah McLachlan | Géneros: canadian pop, canadian singer-songwriter, pop rock, permanent wave
# 5. Aquarium - Nosaj Thing | Géneros: future garage, glitch hop, indietronica, intelligent dance music
# 6. I Am Trying to Break Your Heart - Wilco | Géneros: roots rock, stomp and holler, alternative rock, indie rock
# 7. Daylight - Matt and Kim | Géneros: brooklyn indie, indietronica, shimmer pop, modern rock
# 8. Alla som inte dansar - Maskinen | Géneros: swedish alternative rock
# 9. No Coffee - Amber Coffman | Géneros: art pop
# 10. Runaway Train - Soul Asylum | Géneros: grunge, alternative rock, post-grunge, pop rock
#
# Recomendaciones para el usuario 7:
# 1. TV Party - Black Flag | Géneros: alternative rock, california hardcore, hardcore punk, punk
# 2. Ohne Dich (schlaf' ich heut Nacht nicht ein) - Münchener Freiheit | Géneros: german pop rock, german pop, austropop, ostrock
# 10. Sexual Healing - Kygo Radio Edit - Marvin Gaye, Kygo | Géneros: edm, northern soul, tropical house, pop
#
# Recomendaciones para el usuario 10:
# 1. Can't Do Without You - Caribou | Géneros: indietronica, trip hop, intelligent dance music, electronica
# 2. This Will Be Our Year - The Zombies | Géneros: psychedelic rock, folk rock, baroque pop, classic rock
# 3. Sonata No. 14 "Moonlight" in C-Sharp Minor", Op. 27 No. 2: I. Adagio sostenuto - Ludwig van Beethoven, Paul Lewis | Géneros: classical era, british classical piano, early romantic era, german romanticism
# 4. Californication - Red Hot Chili Peppers | Géneros: rock, alternative rock, funk metal, funk rock
# 5. Blood - Breaking Benjamin | Géneros: post-grunge, alternative metal, nu metal
# 6. Strong - London Grammar | Géneros: metropopolis, nottingham indie
# 7. Goodmorning - Bleachers | Géneros: indie pop, pov: indie, indie poptimism, modern rock
# 8. Paralyzer - Finger Eleven | Géneros: post-grunge, canadian rock, alternative metal, nu metal
# 9. Dial 666 - Night Beats | Géneros: garage rock, garage pop, neo-psychedelic
# 10. Coming Home - Leon Bridges | Géneros: modern blues, neo soul, soul
#
# Recomendaciones para el usuario 11:
# 1. Playground Love (with Gordon Tracks) - Air, Gordon Tracks | Géneros: ambient pop, indietronica, trip hop, downtempo
# 2. Rise - Jonas Blue, Jack & Jack | Géneros: tropical house, pop, teen pop, uk dance
# 3. Stolen Dance - Milky Chance | Géneros: german pop, modern rock
# 4. F*** U (feat. Deepflow, J-Kwondo of 45 RPM) - J-Dogg | Géneros: k-rap
# 5. STREET - NGHTMRE | Géneros: edm, brostep, electro house
# 6. Love Dust (사랑 먼지) - BIGBANG | Géneros: k-pop boy group, k-pop
# 7. Por Voce (For You) - Pudditorium | Géneros: k-indie
# 8. Safe And Sound - Capital Cities | Géneros: metropopolis, modern rock
# 9. Scar Tissue - Red Hot Chili Peppers | Géneros: rock, alternative rock, funk metal, funk rock
# 10. No Rain - Remastered 2002 - Blind Melon | Géneros: rock, grunge, alternative rock, alternative metal
#
# Recomendaciones para el usuario 12:
# 1. Narrow Daylight - Diana Krall | Géneros: vocal jazz, contemporary vocal jazz, jazz pop
# 2. Daylight - Matt and Kim | Géneros: brooklyn indie, indietronica, shimmer pop, modern rock
# 3. Humanos a Marte - Chayanne | Géneros: puerto rican pop, latin pop
# 4. When We Were Young - Andy Black, Juliet Simms | Géneros: deep talent show, pixie
# 5. This Head I Hold - Electric Guest | Géneros: indietronica, shimmer pop, la indie
# 6. Síguelo - Wisin & Yandel | Géneros: reggaeton, electro latino, trap latino, urbano latino
# 7. One More Light - Linkin Park | Géneros: rap metal, rock, post-grunge, alternative metal
# 8. The Passenger - Iggy Pop | Géneros: rock, alternative rock, glam rock, protopunk
# 9. Hay Algo En Ti - Zion & Lennox | Géneros: reggaeton, urbano latino
# 10. Tu Respiración - Chayanne | Géneros: puerto rican pop, latin pop
#
# Recomendaciones para el usuario 13:
# 1. What's My Age Again? - blink-182 | Géneros: rock, socal pop punk, pop punk, alternative metal
# 2. 4 Impromptus, Op. 90, D. 899: Impromptu No. 2 in E-Flat Major - Franz Schubert, Jenő Jandó | Géneros: classical era, early romantic era, classical, hungarian classical piano
# 3. Testify - Rage Against The Machine | Géneros: rap metal, rock, post-grunge, alternative rock
# 4. Evelyn - Goldmund | Géneros: ambient, nu age, compositional ambient
# 5. 3 Intermezzi, Op. 117: No. 3 in C-Sharp Minor, Andante con moto - Johannes Brahms, Glenn Gould | Géneros: late romantic era, canadian classical piano, german romanticism, classical
# 6. 27. May - Original - Yiruma | Géneros: new age piano, korean instrumental, neo-classical
# 7. Tales Of Brave Ulysses - Cream | Géneros: rock, blues rock, supergroup, psychedelic rock
# 8. Heaven's On Fire - KISS | Géneros: glam rock, rock, hard rock
# 9. Electric Feel - MGMT | Géneros: rock, alternative rock, indietronica, indie rock
# 10. Crazy in Love - The Baseballs | Géneros: neo-rockabilly
#
# Recomendaciones para el usuario 14:
# 1. L.A. Girl - Adolescents | Géneros: punk, hardcore punk
# 2. Armed With A Mind - Have Heart | Géneros: chaotic hardcore, boston hardcore, straight edge, melodic hardcore
# 3. Stranglehold - Ted Nugent | Géneros: rock, blues rock, glam metal, southern rock
# 4. Dirty Paws - Of Monsters and Men | Géneros: modern rock, metropopolis, stomp and holler, folk-pop
# 5. Girls - Beastie Boys | Géneros: hip hop, rock, alternative rock, east coast hip hop
# 6. Jah Calling - Bad Brains | Géneros: dc hardcore, nyhc, hardcore punk, punk
# 7. Hard To Handle - The Black Crowes | Géneros: rock, blues rock, jam band, southern rock
# 8. Alive - Pearl Jam | Géneros: rock, grunge, alternative rock, alternative metal
# 9. Switch Lanes - Tyga, The Game | Géneros: trap, detroit hip hop, hip hop, southern hip hop
# 10. Stubborn Love - The Lumineers | Géneros: neo mellow, modern rock, stomp and holler, folk-pop
#
# Recomendaciones para el usuario 15:
# 1. Weak - AJR | Géneros: pov: indie
# 2. Dead And Gone - T.I., Justin Timberlake | Géneros: trap, atl hip hop, hip hop, southern hip hop
# 3. Waiting For Love - Tundran Remix - Avicii, Tundran | Géneros: edm, pop, dance pop, pop dance
# 4. In The Night - The Weeknd | Géneros: pop, canadian contemporary r&b, canadian pop
# 5. La Raza - Kid Frost | Géneros: chicano rap
# 6. Sweet Creature - Harry Styles | Géneros: pop
# 7. Switch - 6LACK | Géneros: trap, atl hip hop, r&b, rap
# 8. No Flag (feat. Nicki Minaj, 21 Savage & Offset) - London On Da Track, Nicki Minaj, 21 Savage, Offset | Géneros: trap, atl hip hop, hip hop, pop
# 9. Outside (feat. Ellie Goulding) - Calvin Harris, Ellie Goulding | Géneros: edm, uk pop, pop, indietronica
# 10. Red Lights - Tiësto | Géneros: edm, slap house, trance, big room
#
# Recomendaciones para el usuario 16:
# 1. Don't Answer The Door - B.B. King | Géneros: blues rock, soul blues, soul, blues
# 2. Boom Boom - John Lee Hooker | Géneros: blues rock, delta blues, memphis blues, blues
# 3. Misery Business - Paramore | Géneros: rock, pop, pixie, pop emo
# 4. Sunny - Boney M. | Géneros: europop
# 5. My Home Is In The Delta - Muddy Waters | Géneros: blues rock, chicago blues, soul, blues
# 8. Carmen, Act II: No.12 Chanson Bohème : Les tringles des sistres tintaient avec un éclat métallique (Carmen/Frasquita/Mercédès) - Angela Gheorghiu | Géneros: opera, classical soprano
# 9. Le nozze di Figaro, K. 492, Act II: No. 12, Voi che sapete - Wolfgang Amadeus Mozart, Cecilia Bartoli, Wiener Philharmoniker, Claudio Abbado | Géneros: classical era, opera, orchestra, classical performance
# 10. Sunflower - Spider-Man: Into the Spider-Verse - Post Malone, Swae Lee | Géneros: trap, dfw rap, pop, rap
#
# Recomendaciones para el usuario 19:
# 1. Mama Said - Lukas Graham | Géneros: danish pop, scandipop
# 2. King's Dead (with Kendrick Lamar, Future & James Blake) - Jay Rock, Kendrick Lamar, Future, James Blake | Géneros: trap, atl hip hop, hip hop, indie soul
# 3. Talking Body - Tove Lo | Géneros: pop, swedish electropop, metropopolis, swedish pop
# 4. Relationship (feat. Future) - Young Thug, Future | Géneros: trap, atl hip hop, hip hop, southern hip hop
# 5. Let You Down - NF | Géneros: pop rap, hip hop
# 6. How Deep Is Your Love - Calvin Harris, Disciples | Géneros: edm, pop, house, electro house
# 7. Turn Down for What - DJ Snake, Lil Jon | Géneros: edm, trap, atl hip hop, southern hip hop
# 8. Fight Night - Migos | Géneros: trap, atl hip hop, hip hop, pop rap
# 9. Thunder - Imagine Dragons | Géneros: pop, rock, modern rock
# 10. Trap Queen - Fetty Wap | Géneros: new jersey rap, trap, southern hip hop, pop rap
#
# Recomendaciones para el usuario 20:
# 1. 사과 - Pudditorium | Géneros: k-indie
# 2. Headlights (feat. Ilsey) - Robin Schulz, Ilsey | Géneros: edm, tropical house, german dance, deep euro house
# 3. Monday - Ludovico Einaudi | Géneros: neo-classical, compositional ambient
# 4. Love Myself - Hailee Steinfeld | Géneros: pop
# 5. Début - Mélanie Laurent | Géneros: french pop
# 6. Far Nearer - Jamie xx | Géneros: electronica, future garage, indie soul, indietronica
# 7. Fantastic Boy - BIGBANG | Géneros: k-pop boy group, k-pop
# 8. Where Ya At (feat. Drake) - Future, Drake | Géneros: trap, atl hip hop, hip hop, southern hip hop
# 9. Thinking About You (feat. Ayah Marar) - Calvin Harris, Ayah Marar | Géneros: edm, jordanian pop, pop, house
# 10. Eros - Ludovico Einaudi | Géneros: neo-classical, compositional ambient
#
# Recomendaciones guardadas en recommendations_per_user.csv

# %% [markdown]
# Generos disponibles

# %%
# Obtener los géneros disponibles
available_genres = sp.recommendation_genre_seeds()['genres']
print("Géneros disponibles en Spotify:")
print(available_genres)
# Out:
# Géneros disponibles en Spotify:
# ['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient', 'anime', 'black-metal', 'bluegrass', 'blues', 'bossanova', 'brazil', 'breakbeat', 'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical', 'club', 'comedy', 'country', 'dance', 'dancehall', 'death-metal', 'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies', 'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party', 'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-pop', 'progressive-house', 'psych-rock', 'punk', 'punk-rock', 'r-n-b', 'rainy-day', 'reggae', 'reggaeton', 'road-trip', 'rock', 'rock-n-roll', 'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo', 'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter', 'soul', 'soundtracks', 'spanish', 'study', 'summer', 'swedish', 'synth-pop', 'tango', 'techno', 'trance', 'trip-hop', 'turkish', 'work-out', 'world-music']

# %% [markdown]
# Ultimo test

# %%
import pandas as pd
import difflib

# Lista de géneros soportados por Spotify
spotify_genres = [
    'acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient', 'anime',
    'black-metal', 'bluegrass', 'blues', 'bossanova', 'brazil', 'breakbeat',
    'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical',
    'club', 'comedy', 'country', 'dance', 'dancehall', 'death-metal',
    'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub',
    'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french',
    'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
    'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
    'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm',
    'indian', 'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol',
    'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay',
    'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies',
    'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party',
    'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-pop',
    'progressive-house', 'psych-rock', 'punk', 'punk-rock', 'r-n-b', 'rainy-day',
    'reggae', 'reggaeton', 'road-trip', 'rock', 'rock-n-roll', 'rockabilly',
    'romance', 'sad', 'salsa', 'samba', 'sertanejo', 'show-tunes',
    'singer-songwriter', 'ska', 'sleep', 'songwriter', 'soul', 'soundtracks',
    'spanish', 'study', 'summer', 'swedish', 'synth-pop', 'tango', 'techno',
    'trance', 'trip-hop', 'turkish', 'work-out', 'world-music'
]

# Función para encontrar el género más cercano permitido por Spotify
def find_closest_genre(genre, spotify_genres):
    closest_matches = difflib.get_close_matches(genre, spotify_genres, n=1, cutoff=0.6)
    return closest_matches[0] if closest_matches else None

# Función para convertir los géneros de usuario a géneros de Spotify y guardarlos
def convert_and_save_genres(df):
    converted_genres_list = []
    artists_list = []
    user_ids = []
    counts = []

    for index, row in df.iterrows():
        if row['type'] == 'genre':
            genre = row['name'].strip()
            closest_genre = find_closest_genre(genre, spotify_genres)
            if closest_genre:
                converted_genres_list.append(closest_genre)
                artists_list.append(row['name'])  # Agregar nombre del artista
                user_ids.append(row['user_id'])   # Agregar user_id
                counts.append(row['count'])       # Agregar count

    # Crear DataFrame con los resultados
    result_df = pd.DataFrame({
        'artist': artists_list,
        'converted_genres': converted_genres_list,
        'user_id': user_ids,
        'count': counts
    })

    # Guardar los resultados en un nuevo CSV
    result_df.to_csv('converted_genres_extended.csv', index=False)
    print("Converted genres with artist names and user_ids saved to converted_genres_extended.csv")

# Cargar el dataset original
df = pd.read_csv('/content/all_favorites.csv')

# Filtrar solo las filas de tipo 'genre'
genres_df = df[df['type'] == 'genre']

# Convertir y guardar los géneros con información extendida
convert_and_save_genres(genres_df)
# Out:
# Converted genres with artist names and user_ids saved to converted_genres_extended.csv

# %% [markdown]
# Error de recomendacion

# %%
# Función para obtener información de una canción
def get_song_info(song_name):
    results = sp.search(q=song_name, limit=1)
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        artist_info = sp.artist(track['artists'][0]['id'])
        song_info = {
            'song_name': track['name'],
            'artist': track['artists'][0]['name'],
            'genre': ', '.join(artist_info['genres']) if artist_info['genres'] else 'Not Available',
            'popularity': track['popularity'],
            'duration': f"{track['duration_ms'] // 60000} min {track['duration_ms'] % 60000 // 1000} s",
            'album_name': track['album']['name'],
            'album_release_date': track['album']['release_date']
        }
        return song_info
    else:
        return None

# Función para obtener información de canciones para un usuario
def get_user_song_info(user_id, df):
    user_songs = df[df['user_id'] == user_id]['song_name']
    song_infos = [get_song_info(song) for song in user_songs]
    song_infos = [info for info in song_infos if info is not None]
    song_info_df = pd.DataFrame(song_infos)
    return song_info_df

# Función para obtener los artistas y géneros favoritos
def get_favorite_artists_genres(song_info_df, user_id):
    artist_counts = song_info_df['artist'].value_counts().reset_index()
    artist_counts.columns = ['name', 'count']
    artist_counts['type'] = 'artist'
    artist_counts['user_id'] = user_id

    genre_counts = song_info_df['genre'].str.split(', ').explode().value_counts().reset_index()
    genre_counts.columns = ['name', 'count']
    genre_counts['type'] = 'genre'
    genre_counts['user_id'] = user_id

    return artist_counts, genre_counts

# Función para obtener recomendaciones
def get_recommendations(artists, genres, limit=10):
    recommendations = sp.recommendations(seed_artists=artists, seed_genres=genres, limit=limit)
    rec_tracks = []
    for track in recommendations['tracks']:
        rec_tracks.append({
            'song_name': track['name'],
            'artist': track['artists'][0]['name'],
            'album_name': track['album']['name'],
            'popularity': track['popularity'],
            'duration_ms': f"{track['duration_ms'] // 60000} min {track['duration_ms'] % 60000 // 1000} s",
            'album_release_date': track['album']['release_date']
        })
    return rec_tracks

# Función para obtener recomendaciones para todos los usuarios
def recommend_songs_for_all_users(df):
    user_ids = df['user_id'].unique()
    all_recommendations = pd.DataFrame()

    for user_id in user_ids:
        song_info_df = get_user_song_info(user_id, df)
        print(f"Obteniendo recomendaciones para el usuario {user_id}.")

        # Obtener artistas y géneros favoritos
        favorite_artists, favorite_genres = get_favorite_artists_genres(song_info_df, user_id)

        # Seleccionar algunos artistas y géneros como semillas para las recomendaciones
        seed_artists = favorite_artists['name'].head(5).tolist()  # Top 5 artistas
        seed_genres = favorite_genres['name'].head(5).tolist()  # Top 5 géneros

        # Obtener recomendaciones
        rec_tracks = get_recommendations(seed_artists, seed_genres)

        # Agregar ID de usuario a las recomendaciones
        for rec in rec_tracks:
            rec['user_id'] = user_id

        # Convertir a DataFrame y concatenar
        rec_df = pd.DataFrame(rec_tracks)
        all_recommendations = pd.concat([all_recommendations, rec_df], ignore_index=True)

        # Imprimir recomendaciones para el usuario actual
        print(f"Recomendaciones para el usuario {user_id}:")
        print(rec_df)

    return all_recommendations

# Cargar el archivo CSV
df = pd.read_csv('/content/users_info.csv')

# Limpiar los nombres de las columnas eliminando espacios iniciales y finales
df.columns = df.columns.str.strip()

# Obtener recomendaciones para todos los usuarios y guardarlas en un archivo CSV
all_recommendations = recommend_songs_for_all_users(df)
all_recommendations.to_csv('/mnt/data/all_recommendations.csv', index=False)

print("Recomendaciones de canciones para todos los usuarios guardadas en all_recommendations.csv.")
# Out:
# Obteniendo recomendaciones para el usuario 1.
# ---------------------------------------------------------------------------
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-33-ec6d8db05585> in <cell line: 97>()
#      95
#      96 # Obtener recomendaciones para todos los usuarios y guardarlas en un archivo CSV
# ---> 97 all_recommendations = recommend_songs_for_all_users(df)
#      98 all_recommendations.to_csv('/mnt/data/all_recommendations.csv', index=False)
#      99
#
# <ipython-input-33-ec6d8db05585> in recommend_songs_for_all_users(df)
#      72
#      73         # Obtener recomendaciones
# ---> 74         rec_tracks = get_recommendations(seed_artists, seed_genres)
#      75
#      76         # Agregar ID de usuario a las recomendaciones
#
# <ipython-input-33-ec6d8db05585> in get_recommendations(artists, genres, limit)
#      42 # Función para obtener recomendaciones
#      43 def get_recommendations(artists, genres, limit=10):
# ---> 44     recommendations = sp.recommendations(seed_artists=artists, seed_genres=genres, limit=limit)
#      45     rec_tracks = []
#      46     for track in recommendations['tracks']:
#
# /usr/local/lib/python3.10/dist-packages/spotipy/client.py in recommendations(self, seed_artists, seed_genres, seed_tracks, limit, country, **kwargs)
#    1695         if seed_artists:
#    1696             params["seed_artists"] = ",".join(
# -> 1697                 [self._get_id("artist", a) for a in seed_artists]
#    1698             )
#    1699         if seed_genres:
#
# /usr/local/lib/python3.10/dist-packages/spotipy/client.py in <listcomp>(.0)
#    1695         if seed_artists:
#    1696             params["seed_artists"] = ",".join(
# -> 1697                 [self._get_id("artist", a) for a in seed_artists]
#    1698             )
#    1699         if seed_genres:
#
# /usr/local/lib/python3.10/dist-packages/spotipy/client.py in _get_id(self, type, id)
#    2004
#    2005         # TODO change to a ValueError in v3
# -> 2006         raise SpotifyException(400, -1, "Unsupported URL / URI.")
#    2007
#    2008     def _get_uri(self, type, id):
#
# SpotifyException: http status: 400, code:-1 - Unsupported URL / URI., reason: None
